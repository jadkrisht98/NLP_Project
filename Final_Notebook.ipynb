# %% [markdown]
# #### Part 1 Data Preprocessing and Transformation

# %%
# Importing Libraries
import pandas as pd
import json
import ast
import matplotlib.pyplot as plt
import seaborn as sns   
import numpy as np  
import re
import sklearn

# %%
#Importing Jason mapping file

with open('mappings.json_(DS_A-L2).json', 'r') as f:
    data = json.load(f)
rows = [
    {'tag': tag, 'offering': values[0], 'destination': values[1]}
    for tag, values in data['tags_mapping'].items()
]

df_tags = pd.DataFrame(rows)
df_tags
# Out:
#                       tag                    offering destination
# 0    c07bbh0cu1iccnqmcq00               Accommodation        Abha
# 1    c07bbj4bb64t6si78rh0             Food & Beverage        Abha
# 2    c07bbvvepd3oq1r122o0                      Retail        Abha
# 3    c9g7nos8hb0qun2qahmg                   Religious        Abha
# 4    c9g7o87epd3vh6lri8bg  Tourism Attractions/ Sites        Abha
# ..                    ...                         ...         ...
# 108  c9g97fk8hb0qun2qahu0                   Religious      Qassim
# 109  c9g97g4bb64rs4ni6s00                      Retail      Qassim
# 110  c9g97ggcu1ielf8dr39g  Tourism Attractions/ Sites      Qassim
# 111  c9g9s70cu1ielf8dr3dg             Food & Beverage     Tanomah
# 112  c9g9s7sbb64rs4ni6s6g  Tourism Attractions/ Sites     Tanomah
#
# [113 rows x 3 columns]

# %%
print(df_tags['offering'].unique())
# Out:
# ['Accommodation' 'Food & Beverage' 'Retail' 'Religious'
#  'Tourism Attractions/ Sites']

# %%
print(df_tags['destination'].unique())
# Out:
# ['Abha' 'Al Ahsa' 'Al Baha' 'Al Ula' 'Dammam' 'Hail' 'Jeddah' 'Jizan'
#  'KAEC' 'Khobar' 'Madinah' 'Makkah' 'Tabuk' 'Taif' 'Umluj' 'Yanbu'
#  'Al Diriyah' 'Sakaka / AlJouf' 'Riyadh' 'Al Namas' 'Al Wajh' 'Duba'
#  'NEOM' 'Qassim' 'Tanomah']

# %%
#Import Customer feedback dataset

feedback_df = pd.read_csv('dataset.csv_(DS_A-L2).csv')
feedback_df
# Out:
#                        id                                            content  \
# 0     377380-203583770957  من الاماكن الهاديه الجميله الممتعه في التسوق ت...
# 1     377380-203585579625  مساحة خضراء تتنفس فيها الهواء النقي .. المناظر...
# 2     377380-203590496913                                         nice place
# 3     377380-203589330972                                              جميل❤
# 4     377380-203586632060                                             جميييل
# ...                   ...                                                ...
# 9995  377380-170059072985  More(Translated by Google) The mosque is curre...
# 9996  377380-168116614508  More(Translated by Google) The best branch of ...
# 9997  377380-170027061275                                         الأكل عادي
# 9998  377380-167887315495                                     سوق كبير وجميل
# 9999  377380-170021789104                                               روعة
#
#                            date language  \
# 0     2021-04-11T06:45:00+00:00      ara
# 1     2021-04-11T06:45:00+00:00      ara
# 2     2021-04-11T06:45:00+00:00      eng
# 3     2021-04-11T06:45:00+00:00      ara
# 4     2021-04-11T06:45:00+00:00      ara
# ...                         ...      ...
# 9995  2021-02-15T00:00:00+00:00      ara
# 9996  2021-02-15T00:00:00+00:00      ara
# 9997  2021-02-15T00:00:00+00:00      ara
# 9998  2021-02-15T00:00:00+00:00      ara
# 9999  2021-02-15T00:00:00+00:00      ara
#
#                                                    tags  \
# 0     [{'value': 'c07bdfc8hb0r13sa7agg', 'sentiment'...
# 1     [{'value': 'c07bdncbb64t6si78ssg', 'sentiment'...
# 2     [{'value': 'c0rlhqgcu1i938rekca0', 'sentiment'...
# 3     [{'value': 'c9ga0skbb64rs4ni6s7g', 'sentiment'...
# 4     [{'value': 'c07bdncbb64t6si78ssg', 'sentiment'...
# ...                                                 ...
# 9995  [{'value': 'c07bdfc8hb0r13sa7agg', 'sentiment'...
# 9996  [{'value': 'c07bdifepd3oq1r122r0', 'sentiment'...
# 9997  [{'value': 'c07bk44bb64t6si78v80', 'sentiment'...
# 9998  [{'value': 'c0rqvf8cu1i938rekgn0', 'sentiment'...
# 9999  [{'value': 'c07bdifepd3oq1r122r0', 'sentiment'...
#
#                                         title                        ratings
# 0             Al Ahsa Mall by Arabian Centres  {'normalized': 100, 'raw': 5}
# 1               King Abdullah Park, Sea front  {'normalized': 100, 'raw': 5}
# 2                       Green Mountain Resort  {'normalized': 100, 'raw': 5}
# 3     Waterfront Beach Royal Commission Yanbu   {'normalized': 80, 'raw': 4}
# 4                             Dammam Corniche  {'normalized': 100, 'raw': 5}
# ...                                       ...                            ...
# 9995                           Jawatha Mosque   {'normalized': 60, 'raw': 3}
# 9996                Burger King - Enoc Dareen   {'normalized': 80, 'raw': 4}
# 9997                              Güzel Saray   {'normalized': 60, 'raw': 3}
# 9998                      Riyadh Gallery Mall   {'normalized': 80, 'raw': 4}
# 9999              Burger King - Al Safa Plaza  {'normalized': 100, 'raw': 5}
#
# [10000 rows x 7 columns]

# %%
# Check for missing values
feedback_df.isnull().sum()
# Out:
# id           0
# content      0
# date         0
# language     0
# tags         0
# title        0
# ratings     10
# dtype: int64

# %%
#Looking into rows with NULL rating (contnent is not clear --> DROP them)
feedback_df[feedback_df.ratings.isnull()]
# Out:
#                        id                                            content  \
# 1213  377380-203592313113                                  ( Google) , , ( )
# 1245  377380-203592306100                                  ( Google) , , ( )
# 1288  377380-203592306933                                    ( Google) - ( )
# 1456  377380-203592309887                          ( Google) - , , , , , ( )
# 1481  377380-203592315650                           ( Google) ( ) Good place
# 1799  377380-203588492010  ( Google) !! Abit , ( ) Awesome!! Abit cold, b...
# 1934  377380-203588498652                                  ( Google) , . ( )
# 2816  377380-203592291403  (Переведено Google) Зоопарк сладок еще раз еще...
# 3189  377380-203592281835  (Переведено Google) Парк очень красивый, не хв...
# 3602  377380-203588466840  (Переведено Google) Лес Рагдан - красивый боль...
#
#                            date language  \
# 1213  2021-04-11T07:14:00+00:00      eng
# 1245  2021-04-11T07:15:00+00:00      eng
# 1288  2021-04-11T07:16:00+00:00      eng
# 1456  2021-04-11T07:19:00+00:00      eng
# 1481  2021-04-11T07:20:00+00:00      eng
# 1799  2021-04-11T07:27:00+00:00      eng
# 1934  2021-04-11T07:31:00+00:00      eng
# 2816  2021-04-11T07:52:00+00:00      ara
# 3189  2021-04-11T08:01:00+00:00      ara
# 3602  2021-04-11T08:11:00+00:00      ara
#
#                                                    tags                 title  \
# 1213  [{'value': 'c07bdofepd3oq1r123kg', 'sentiment'...            Riyadh Zoo
# 1245  [{'value': 'c07bdofepd3oq1r123kg', 'sentiment'...            Riyadh Zoo
# 1288  [{'value': 'c07bdofepd3oq1r123kg', 'sentiment'...            Riyadh Zoo
# 1456  [{'value': 'c07bdofepd3oq1r123kg', 'sentiment'...            Riyadh Zoo
# 1481  [{'value': 'c07bdofepd3oq1r123kg', 'sentiment'...            Riyadh Zoo
# 1799  [{'value': 'c9g7u348hb0qun2qahng', 'sentiment'...  Raghadan Forest Park
# 1934  [{'value': 'c9g7u348hb0qun2qahng', 'sentiment'...  Raghadan Forest Park
# 2816  [{'value': 'c07bdofepd3oq1r123kg', 'sentiment'...            Riyadh Zoo
# 3189  [{'value': 'c07bdkkbb64t6si78s30', 'sentiment'...            Riyadh Zoo
# 3602  [{'value': 'c9g7u348hb0qun2qahng', 'sentiment'...  Raghadan Forest Park
#
#      ratings
# 1213     NaN
# 1245     NaN
# 1288     NaN
# 1456     NaN
# 1481     NaN
# 1799     NaN
# 1934     NaN
# 2816     NaN
# 3189     NaN
# 3602     NaN

# %%
#drop row will null rating
feedback_df = feedback_df.dropna(subset=['ratings'])

# %%
#Checking for duplicates
feedback_df.drop('tags',axis=1).duplicated().sum()
# Out:
# 11

# %%
feedback_df[feedback_df.duplicated(keep=False)].sort_values(by='content')
# Out:
#                        id                                            content  \
# 7378  377380-167656398451  More(Translated by Google) And God is an excel...
# 7358  377380-167656398451  More(Translated by Google) And God is an excel...
# 7368  377380-167972760325  More(Translated by Google) Best Arabic coffee ...
# 7356  377380-167972760325  More(Translated by Google) Best Arabic coffee ...
# 7357  377380-167750997640  More(Translated by Google) One of the largest ...
# 7377  377380-167750997640  More(Translated by Google) One of the largest ...
# 6331  377380-167303028855  اجيك يسلم راسك وشلون ما جيك .. الذ والذ استلذا...
# 6442  377380-167303028855  اجيك يسلم راسك وشلون ما جيك .. الذ والذ استلذا...
# 821   377380-203582792636                            تحتاج خلاط وتطلع ممتازه
# 825   377380-203582792636                            تحتاج خلاط وتطلع ممتازه
# 7375  377380-169776419512                                               جميل
# 7360  377380-169776419512                                               جميل
# 6440  377380-167674318288                                               جميل
# 6330  377380-167674318288                                               جميل
# 6445  377380-167514637736                                         جميل ومنظم
# 6333  377380-167514637736                                         جميل ومنظم
# 6332  377380-167517004446                                              متنوع
# 6443  377380-167517004446                                              متنوع
# 824   377380-203583752857                                              ممتاز
# 820   377380-203583752857                                              ممتاز
# 1696  377380-203584587118                        ناقصه بعض الاهتمام والخدمات
# 1692  377380-203584587118                        ناقصه بعض الاهتمام والخدمات
#
#                            date language  \
# 7378  2021-02-11T00:00:00+00:00      ara
# 7358  2021-02-11T00:00:00+00:00      ara
# 7368  2021-02-11T00:00:00+00:00      eng
# 7356  2021-02-11T00:00:00+00:00      eng
# 7357  2021-02-11T00:00:00+00:00      ara
# 7377  2021-02-11T00:00:00+00:00      ara
# 6331  2021-02-09T00:00:00+00:00      ara
# 6442  2021-02-09T00:00:00+00:00      ara
# 821   2021-04-11T07:05:00+00:00      ara
# 825   2021-04-11T07:05:00+00:00      ara
# 7375  2021-02-11T00:00:00+00:00      ara
# 7360  2021-02-11T00:00:00+00:00      ara
# 6440  2021-02-09T00:00:00+00:00      ara
# 6330  2021-02-09T00:00:00+00:00      ara
# 6445  2021-02-09T00:00:00+00:00      ara
# 6333  2021-02-09T00:00:00+00:00      ara
# 6332  2021-02-09T00:00:00+00:00      ara
# 6443  2021-02-09T00:00:00+00:00      ara
# 824   2021-04-11T07:05:00+00:00      ara
# 820   2021-04-11T07:05:00+00:00      ara
# 1696  2021-04-11T07:24:00+00:00      ara
# 1692  2021-04-11T07:24:00+00:00      ara
#
#                                                    tags  \
# 7378  [{'value': 'c0rquskbb64sdb6ukkq0', 'sentiment'...
# 7358  [{'value': 'c0rquskbb64sdb6ukkq0', 'sentiment'...
# 7368  [{'value': 'c07bdkkbb64t6si78s2g', 'sentiment'...
# 7356  [{'value': 'c07bdkkbb64t6si78s2g', 'sentiment'...
# 7357  [{'value': 'c0rqvf8cu1i938rekgn0', 'sentiment'...
# 7377  [{'value': 'c0rqvf8cu1i938rekgn0', 'sentiment'...
# 6331  [{'value': 'c0rquskbb64sdb6ukkq0', 'sentiment'...
# 6442  [{'value': 'c0rquskbb64sdb6ukkq0', 'sentiment'...
# 821   [{'value': 'c07bdfc8hb0r13sa7ag0', 'sentiment'...
# 825   [{'value': 'c07bdfc8hb0r13sa7ag0', 'sentiment'...
# 7375  [{'value': 'c07bjr48hb0r13sa7c8g', 'sentiment'...
# 7360  [{'value': 'c07bjr48hb0r13sa7c8g', 'sentiment'...
# 6440  [{'value': 'c07bdofepd3oq1r123qg', 'sentiment'...
# 6330  [{'value': 'c07bdofepd3oq1r123qg', 'sentiment'...
# 6445  [{'value': 'c07bbvvepd3oq1r122o0', 'sentiment'...
# 6333  [{'value': 'c07bbvvepd3oq1r122o0', 'sentiment'...
# 6332  [{'value': 'c07bdkkbb64t6si78s3g', 'sentiment'...
# 6443  [{'value': 'c07bdkkbb64t6si78s3g', 'sentiment'...
# 824   [{'value': 'c07bdfc8hb0r13sa7agg', 'sentiment'...
# 820   [{'value': 'c07bdfc8hb0r13sa7agg', 'sentiment'...
# 1696  [{'value': 'c9g9th4bb64rs4ni6s70', 'sentiment'...
# 1692  [{'value': 'c9g9th4bb64rs4ni6s70', 'sentiment'...
#
#                                 title                        ratings
# 7378                  Kaboria Seafood  {'normalized': 100, 'raw': 5}
# 7358                  Kaboria Seafood  {'normalized': 100, 'raw': 5}
# 7368                 Haif & Kaif Cafe   {'normalized': 80, 'raw': 4}
# 7356                 Haif & Kaif Cafe   {'normalized': 80, 'raw': 4}
# 7357                       Hayat Mall  {'normalized': 100, 'raw': 5}
# 7377                       Hayat Mall  {'normalized': 100, 'raw': 5}
# 6331        Ibrahim Al Zahrani Grills  {'normalized': 100, 'raw': 5}
# 6442        Ibrahim Al Zahrani Grills  {'normalized': 100, 'raw': 5}
# 821                       Uqair Beach  {'normalized': 100, 'raw': 5}
# 825                       Uqair Beach  {'normalized': 100, 'raw': 5}
# 7375                  Al Tawba Mosque  {'normalized': 100, 'raw': 5}
# 7360                  Al Tawba Mosque  {'normalized': 100, 'raw': 5}
# 6440                The Seven Mosques  {'normalized': 100, 'raw': 5}
# 6330                The Seven Mosques  {'normalized': 100, 'raw': 5}
# 6445                       Aseer Mall  {'normalized': 100, 'raw': 5}
# 6333                       Aseer Mall  {'normalized': 100, 'raw': 5}
# 6332                 Al Mahmal Center  {'normalized': 100, 'raw': 5}
# 6443                 Al Mahmal Center  {'normalized': 100, 'raw': 5}
# 824   Al Ahsa Mall by Arabian Centres  {'normalized': 100, 'raw': 5}
# 820   Al Ahsa Mall by Arabian Centres  {'normalized': 100, 'raw': 5}
# 1696                      Umluj Beach   {'normalized': 60, 'raw': 3}
# 1692                      Umluj Beach   {'normalized': 60, 'raw': 3}

# %%
#Drop duplicated rows
feedback_df = feedback_df.drop_duplicates(subset=feedback_df.columns.difference(['tags']))

# %%
#Row with only emojis in content

def is_only_emojis(text):
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F1E0-\U0001F1FF"  # flags
        "\U00002700-\U000027BF"  # Dingbats
        "\U000024C2-\U0001F251"
        "]+", flags=re.UNICODE)
    cleaned = emoji_pattern.sub('', str(text)).strip()
    return cleaned == ''

feedback_df[feedback_df['content'].apply(is_only_emojis)]
# Out:
#                        id   content                       date language  \
# 188   377380-203589373533        👍👍  2021-04-11T06:50:00+00:00      eng
# 446   377380-203588636362         😊  2021-04-11T06:56:00+00:00      eng
# 732   377380-203587032505        👍🏻  2021-04-11T07:03:00+00:00      eng
# 759   377380-203584368249       👍💞💞  2021-04-11T07:04:00+00:00      eng
# 774   377380-203590458986         😘  2021-04-11T07:04:00+00:00      eng
# 1125  377380-203587479887       👍👍👍  2021-04-11T07:12:00+00:00      eng
# 2761  377380-203583706809      👍🏽👍🏽  2021-04-11T07:51:00+00:00      eng
# 2783  377380-203585828099         👍  2021-04-11T07:52:00+00:00      eng
# 2838  377380-203584979382     ✅✅✅✅✅  2021-04-11T07:53:00+00:00      eng
# 3548  377380-203584551079         😍  2021-04-11T08:10:00+00:00      eng
# 3601  377380-203584764963  👍🏻👍🏻👍🏻👍🏻  2021-04-11T08:11:00+00:00      eng
# 3714  377380-203590554613         💚  2021-04-11T08:13:00+00:00      eng
# 3776  377380-203585937845      ♥️♥️  2021-04-11T08:15:00+00:00      eng
# 3908  377380-203585861479       ❤❤👍  2021-04-11T08:17:00+00:00      eng
# 4133  377380-203588859461         👍  2021-04-11T08:22:00+00:00      eng
# 4138  377380-203582361433        👍😁  2021-04-11T08:22:00+00:00      eng
# 4142  377380-203582350004        👍😁  2021-04-11T08:22:00+00:00      eng
# 4222  377380-203583666341         🌹  2021-04-11T08:24:00+00:00      eng
# 4224  377380-203587450599        😍😍  2021-04-11T08:24:00+00:00      eng
# 4349  377380-203587750558        😍😍  2021-04-11T08:26:00+00:00      eng
# 4632  377380-203583649722         👍  2021-04-11T08:32:00+00:00      eng
# 4893  377380-203584746508        ♥️  2021-04-11T08:38:00+00:00      eng
# 5089  377380-203586176793        👍🏻  2021-04-11T08:42:00+00:00      eng
# 5187  377380-203583639508         👎  2021-04-11T08:43:00+00:00      eng
# 5209  377380-203582920690         ❣  2021-04-11T08:43:00+00:00      eng
# 5999  377380-171916226640       ❤ ❤  2021-02-08T10:40:00+00:00      eng
# 7280  377380-167750014956      ★★★★  2021-02-11T00:00:00+00:00      eng
# 7647  377380-167594355309    ❤️❤️❤️  2021-02-11T03:22:00+00:00      eng
#
#                                                    tags  \
# 188   [{'value': 'c9ga0skbb64rs4ni6s7g', 'sentiment'...
# 446   [{'value': 'c0rlhqgcu1i938rekca0', 'sentiment'...
# 732   [{'value': 'c07bdkkbb64t6si78s3g', 'sentiment'...
# 759   [{'value': 'c07bdncbb64t6si78ssg', 'sentiment'...
# 774   [{'value': 'c0rlhqgcu1i938rekca0', 'sentiment'...
# 1125  [{'value': 'c9g9fck8hb0qun2qahug', 'sentiment'...
# 2761  [{'value': 'c9g869k8hb0qun2qahp0', 'sentiment'...
# 2783  [{'value': 'c07bdncbb64t6si78ssg', 'sentiment'...
# 2838  [{'value': 'c07bdncbb64t6si78ssg', 'sentiment'...
# 3548  [{'value': 'c9g9th4bb64rs4ni6s70', 'sentiment'...
# 3601  [{'value': 'c07bdncbb64t6si78ssg', 'sentiment'...
# 3714  [{'value': 'c9ga0skbb64rs4ni6s7g', 'sentiment'...
# 3776  [{'value': 'c07bdofepd3oq1r123k0', 'sentiment'...
# 3908  [{'value': 'c9g8qqc8hb0qun2qahs0', 'sentiment'...
# 4133  [{'value': 'c9g9s7sbb64rs4ni6s6g', 'sentiment'...
# 4138  [{'value': 'c9g7o87epd3vh6lri8bg', 'sentiment'...
# 4142  [{'value': 'c9g7o87epd3vh6lri8bg', 'sentiment'...
# 4222  [{'value': 'c07bdfc8hb0r13sa7agg', 'sentiment'...
# 4224  [{'value': 'c07bdofepd3oq1r123kg', 'sentiment'...
# 4349  [{'value': 'c07bdofepd3oq1r123kg', 'sentiment'...
# 4632  [{'value': 'c9g869k8hb0qun2qahp0', 'sentiment'...
# 4893  [{'value': 'c07bdncbb64t6si78ssg', 'sentiment'...
# 5089  [{'value': 'c0rqvl48hb0sd7naaepg', 'sentiment'...
# 5187  [{'value': 'c9g869k8hb0qun2qahp0', 'sentiment'...
# 5209  [{'value': 'c07bkec8hb0r13sa7csg', 'sentiment'...
# 5999  [{'value': 'c0rqv8sbb64sdb6ukks0', 'sentiment'...
# 7280  [{'value': 'c0rqvf8cu1i938rekgn0', 'sentiment'...
# 7647  [{'value': 'c07bja4bb64t6si78uog', 'sentiment'...
#
#                                                   title  \
# 188                                         Alsubh Park
# 446                                   Al Hada Cable Car
# 732                                    Al Mahmal Center
# 759                                     Modon Lake Park
# 774                               Green Mountain Resort
# 1125                 12 Springs of Prophet Moses (A.S.)
# 2761                           Al Meger Tourist Village
# 2783                                   Khobar Sea Front
# 2838    King Abdulaziz Center for World Culture - Ithra
# 3548                                        Umluj Beach
# 3601                             Dolphin Village Dammam
# 3714                                    Yanbu Lake Park
# 3776                   Five Elephants Speciality Coffee
# 3908                                          Yam Beach
# 4133                                  Tanomah Waterfall
# 4138                            Al Soudah National Park
# 4142                            Al Soudah National Park
# 4222                    Al Ahsa Mall by Arabian Centres
# 4224  The Saudi National Museum - The Saudi National...
# 4349  The Saudi National Museum - The Saudi National...
# 4632                           Al Meger Tourist Village
# 4893                             Dolphin Village Dammam
# 5089               Imam Turki Bin Abdullah Grand Mosque
# 5187                           Al Meger Tourist Village
# 5209                                       Marid Castle
# 5999                          VOX Cinemas - Riyadh Park
# 7280                           Al Hamra Shopping Center
# 7647         Makkah Clock Royal Tower, A Fairmont Hotel
#
#                             ratings
# 188   {'normalized': 100, 'raw': 5}
# 446   {'normalized': 100, 'raw': 5}
# 732   {'normalized': 100, 'raw': 5}
# 759   {'normalized': 100, 'raw': 5}
# 774   {'normalized': 100, 'raw': 5}
# 1125  {'normalized': 100, 'raw': 5}
# 2761   {'normalized': 60, 'raw': 3}
# 2783  {'normalized': 100, 'raw': 5}
# 2838  {'normalized': 100, 'raw': 5}
# 3548  {'normalized': 100, 'raw': 5}
# 3601  {'normalized': 100, 'raw': 5}
# 3714   {'normalized': 80, 'raw': 4}
# 3776  {'normalized': 100, 'raw': 5}
# 3908  {'normalized': 100, 'raw': 5}
# 4133  {'normalized': 100, 'raw': 5}
# 4138   {'normalized': 80, 'raw': 4}
# 4142   {'normalized': 80, 'raw': 4}
# 4222   {'normalized': 80, 'raw': 4}
# 4224  {'normalized': 100, 'raw': 5}
# 4349  {'normalized': 100, 'raw': 5}
# 4632  {'normalized': 100, 'raw': 5}
# 4893  {'normalized': 100, 'raw': 5}
# 5089  {'normalized': 100, 'raw': 5}
# 5187   {'normalized': 20, 'raw': 1}
# 5209  {'normalized': 100, 'raw': 5}
# 5999  {'normalized': 100, 'raw': 5}
# 7280  {'normalized': 100, 'raw': 5}
# 7647  {'normalized': 100, 'raw': 5}

# %%
#Dropping rows with only emojis
feedback_df = feedback_df[~feedback_df['content'].apply(is_only_emojis)]

# %%
#Invesitgating data types
feedback_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9951 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        9951 non-null   object
#  1   content   9951 non-null   object
#  2   date      9951 non-null   object
#  3   language  9951 non-null   object
#  4   tags      9951 non-null   object
#  5   title     9951 non-null   object
#  6   ratings   9951 non-null   object
# dtypes: object(7)
# memory usage: 621.9+ KB

# %%
#Convert date column to date format 
feedback_df['date'] = pd.to_datetime(feedback_df['date'])

#Convert a string representation of a list to an actual list
feedback_df['tags'] = feedback_df['tags'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
feedback_df['ratings'] = feedback_df['ratings'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
feedback_df
# Out:
#                        id                                            content  \
# 0     377380-203583770957  من الاماكن الهاديه الجميله الممتعه في التسوق ت...
# 1     377380-203585579625  مساحة خضراء تتنفس فيها الهواء النقي .. المناظر...
# 2     377380-203590496913                                         nice place
# 3     377380-203589330972                                              جميل❤
# 4     377380-203586632060                                             جميييل
# ...                   ...                                                ...
# 9995  377380-170059072985  More(Translated by Google) The mosque is curre...
# 9996  377380-168116614508  More(Translated by Google) The best branch of ...
# 9997  377380-170027061275                                         الأكل عادي
# 9998  377380-167887315495                                     سوق كبير وجميل
# 9999  377380-170021789104                                               روعة
#
#                           date language  \
# 0    2021-04-11 06:45:00+00:00      ara
# 1    2021-04-11 06:45:00+00:00      ara
# 2    2021-04-11 06:45:00+00:00      eng
# 3    2021-04-11 06:45:00+00:00      ara
# 4    2021-04-11 06:45:00+00:00      ara
# ...                        ...      ...
# 9995 2021-02-15 00:00:00+00:00      ara
# 9996 2021-02-15 00:00:00+00:00      ara
# 9997 2021-02-15 00:00:00+00:00      ara
# 9998 2021-02-15 00:00:00+00:00      ara
# 9999 2021-02-15 00:00:00+00:00      ara
#
#                                                    tags  \
# 0     [{'value': 'c07bdfc8hb0r13sa7agg', 'sentiment'...
# 1     [{'value': 'c07bdncbb64t6si78ssg', 'sentiment'...
# 2     [{'value': 'c0rlhqgcu1i938rekca0', 'sentiment'...
# 3     [{'value': 'c9ga0skbb64rs4ni6s7g', 'sentiment'...
# 4     [{'value': 'c07bdncbb64t6si78ssg', 'sentiment'...
# ...                                                 ...
# 9995  [{'value': 'c07bdfc8hb0r13sa7agg', 'sentiment'...
# 9996  [{'value': 'c07bdifepd3oq1r122r0', 'sentiment'...
# 9997  [{'value': 'c07bk44bb64t6si78v80', 'sentiment'...
# 9998  [{'value': 'c0rqvf8cu1i938rekgn0', 'sentiment'...
# 9999  [{'value': 'c07bdifepd3oq1r122r0', 'sentiment'...
#
#                                         title                        ratings
# 0             Al Ahsa Mall by Arabian Centres  {'normalized': 100, 'raw': 5}
# 1               King Abdullah Park, Sea front  {'normalized': 100, 'raw': 5}
# 2                       Green Mountain Resort  {'normalized': 100, 'raw': 5}
# 3     Waterfront Beach Royal Commission Yanbu   {'normalized': 80, 'raw': 4}
# 4                             Dammam Corniche  {'normalized': 100, 'raw': 5}
# ...                                       ...                            ...
# 9995                           Jawatha Mosque   {'normalized': 60, 'raw': 3}
# 9996                Burger King - Enoc Dareen   {'normalized': 80, 'raw': 4}
# 9997                              Güzel Saray   {'normalized': 60, 'raw': 3}
# 9998                      Riyadh Gallery Mall   {'normalized': 80, 'raw': 4}
# 9999              Burger King - Al Safa Plaza  {'normalized': 100, 'raw': 5}
#
# [9951 rows x 7 columns]

# %%
#Date Range
date_range = feedback_df['date'].min().date(), feedback_df['date'].max().date()
print(f"Date Range: {date_range[0]} to {date_range[1]}")
# Out:
# Date Range: 2021-02-07 to 2023-10-03

# %%
feedback_df['title'].nunique()
# Out:
# 1058

# %%
#Exploding 'tags' column into individual rows per list entry
feedback_df_exploded = feedback_df.explode('tags')
feedback_df_exploded
# Out:
#                        id                                            content  \
# 0     377380-203583770957  من الاماكن الهاديه الجميله الممتعه في التسوق ت...
# 0     377380-203583770957  من الاماكن الهاديه الجميله الممتعه في التسوق ت...
# 1     377380-203585579625  مساحة خضراء تتنفس فيها الهواء النقي .. المناظر...
# 1     377380-203585579625  مساحة خضراء تتنفس فيها الهواء النقي .. المناظر...
# 1     377380-203585579625  مساحة خضراء تتنفس فيها الهواء النقي .. المناظر...
# ...                   ...                                                ...
# 9995  377380-170059072985  More(Translated by Google) The mosque is curre...
# 9996  377380-168116614508  More(Translated by Google) The best branch of ...
# 9997  377380-170027061275                                         الأكل عادي
# 9998  377380-167887315495                                     سوق كبير وجميل
# 9999  377380-170021789104                                               روعة
#
#                           date language  \
# 0    2021-04-11 06:45:00+00:00      ara
# 0    2021-04-11 06:45:00+00:00      ara
# 1    2021-04-11 06:45:00+00:00      ara
# 1    2021-04-11 06:45:00+00:00      ara
# 1    2021-04-11 06:45:00+00:00      ara
# ...                        ...      ...
# 9995 2021-02-15 00:00:00+00:00      ara
# 9996 2021-02-15 00:00:00+00:00      ara
# 9997 2021-02-15 00:00:00+00:00      ara
# 9998 2021-02-15 00:00:00+00:00      ara
# 9999 2021-02-15 00:00:00+00:00      ara
#
#                                                    tags  \
# 0     {'value': 'c07bdfc8hb0r13sa7agg', 'sentiment':...
# 0     {'value': 'c07bdfc8hb0r13sa7ah0', 'sentiment':...
# 1     {'value': 'c07bdncbb64t6si78ssg', 'sentiment':...
# 1     {'value': 'c07bdofepd3oq1r123kg', 'sentiment':...
# 1     {'value': 'c0rquskbb64sdb6ukkq0', 'sentiment':...
# ...                                                 ...
# 9995  {'value': 'c07bdfc8hb0r13sa7amg', 'sentiment':...
# 9996  {'value': 'c07bdifepd3oq1r122r0', 'sentiment':...
# 9997  {'value': 'c07bk44bb64t6si78v80', 'sentiment':...
# 9998  {'value': 'c0rqvf8cu1i938rekgn0', 'sentiment':...
# 9999  {'value': 'c07bdifepd3oq1r122r0', 'sentiment':...
#
#                                 title                        ratings
# 0     Al Ahsa Mall by Arabian Centres  {'normalized': 100, 'raw': 5}
# 0     Al Ahsa Mall by Arabian Centres  {'normalized': 100, 'raw': 5}
# 1       King Abdullah Park, Sea front  {'normalized': 100, 'raw': 5}
# 1       King Abdullah Park, Sea front  {'normalized': 100, 'raw': 5}
# 1       King Abdullah Park, Sea front  {'normalized': 100, 'raw': 5}
# ...                               ...                            ...
# 9995                   Jawatha Mosque   {'normalized': 60, 'raw': 3}
# 9996        Burger King - Enoc Dareen   {'normalized': 80, 'raw': 4}
# 9997                      Güzel Saray   {'normalized': 60, 'raw': 3}
# 9998              Riyadh Gallery Mall   {'normalized': 80, 'raw': 4}
# 9999      Burger King - Al Safa Plaza  {'normalized': 100, 'raw': 5}
#
# [12931 rows x 7 columns]

# %%
#Replacing 'tags' column with dictionary keys (value & sentiment) as new columns
tags_df = feedback_df_exploded['tags'].apply(pd.Series)
feedback_df_exploded = pd.concat([feedback_df_exploded.drop(columns=['tags']), tags_df], axis=1)
feedback_df_exploded.rename(columns={'value': 'tag'}, inplace=True)

#mapping tag with json file (df_tags) --Extracting Offering and Destination
feedback_df_exploded = feedback_df_exploded.merge(df_tags, on='tag', how='left')

feedback_df_exploded
# Out:
#                         id                                            content  \
# 0      377380-203583770957  من الاماكن الهاديه الجميله الممتعه في التسوق ت...
# 1      377380-203583770957  من الاماكن الهاديه الجميله الممتعه في التسوق ت...
# 2      377380-203585579625  مساحة خضراء تتنفس فيها الهواء النقي .. المناظر...
# 3      377380-203585579625  مساحة خضراء تتنفس فيها الهواء النقي .. المناظر...
# 4      377380-203585579625  مساحة خضراء تتنفس فيها الهواء النقي .. المناظر...
# ...                    ...                                                ...
# 12926  377380-170059072985  More(Translated by Google) The mosque is curre...
# 12927  377380-168116614508  More(Translated by Google) The best branch of ...
# 12928  377380-170027061275                                         الأكل عادي
# 12929  377380-167887315495                                     سوق كبير وجميل
# 12930  377380-170021789104                                               روعة
#
#                            date language                            title  \
# 0     2021-04-11 06:45:00+00:00      ara  Al Ahsa Mall by Arabian Centres
# 1     2021-04-11 06:45:00+00:00      ara  Al Ahsa Mall by Arabian Centres
# 2     2021-04-11 06:45:00+00:00      ara    King Abdullah Park, Sea front
# 3     2021-04-11 06:45:00+00:00      ara    King Abdullah Park, Sea front
# 4     2021-04-11 06:45:00+00:00      ara    King Abdullah Park, Sea front
# ...                         ...      ...                              ...
# 12926 2021-02-15 00:00:00+00:00      ara                   Jawatha Mosque
# 12927 2021-02-15 00:00:00+00:00      ara        Burger King - Enoc Dareen
# 12928 2021-02-15 00:00:00+00:00      ara                      Güzel Saray
# 12929 2021-02-15 00:00:00+00:00      ara              Riyadh Gallery Mall
# 12930 2021-02-15 00:00:00+00:00      ara      Burger King - Al Safa Plaza
#
#                              ratings                   tag sentiment  \
# 0      {'normalized': 100, 'raw': 5}  c07bdfc8hb0r13sa7agg      None
# 1      {'normalized': 100, 'raw': 5}  c07bdfc8hb0r13sa7ah0      None
# 2      {'normalized': 100, 'raw': 5}  c07bdncbb64t6si78ssg      None
# 3      {'normalized': 100, 'raw': 5}  c07bdofepd3oq1r123kg      None
# 4      {'normalized': 100, 'raw': 5}  c0rquskbb64sdb6ukkq0      None
# ...                              ...                   ...       ...
# 12926   {'normalized': 60, 'raw': 3}  c07bdfc8hb0r13sa7amg      None
# 12927   {'normalized': 80, 'raw': 4}  c07bdifepd3oq1r122r0      None
# 12928   {'normalized': 60, 'raw': 3}  c07bk44bb64t6si78v80      None
# 12929   {'normalized': 80, 'raw': 4}  c0rqvf8cu1i938rekgn0      None
# 12930  {'normalized': 100, 'raw': 5}  c07bdifepd3oq1r122r0      None
#
#                          offering destination
# 0      Tourism Attractions/ Sites     Al Ahsa
# 1                          Retail     Al Ahsa
# 2      Tourism Attractions/ Sites      Khobar
# 3      Tourism Attractions/ Sites     Madinah
# 4                   Accommodation      Riyadh
# ...                           ...         ...
# 12926                   Religious     Al Ahsa
# 12927             Food & Beverage      Dammam
# 12928             Food & Beverage       Yanbu
# 12929                      Retail      Riyadh
# 12930             Food & Beverage      Dammam
#
# [12931 rows x 10 columns]

# %%
#Replacing 'ratings' column with keys (normalized & raw) as columns
ratings_df = feedback_df_exploded['ratings'].apply(pd.Series)   
feedback_df_exploded = pd.concat([feedback_df_exploded.drop(columns=['ratings']), ratings_df], axis=1)
feedback_df_exploded.rename(columns={'normalized': 'normalized_rating'}, inplace=True)
feedback_df_exploded.rename(columns={'raw': 'actual_rating'}, inplace=True)

#rearranging columns
feedback_df_exploded = feedback_df_exploded[['id', 'content', 'date', 'language', 'title', 'destination', 'offering','tag', 'normalized_rating', 'actual_rating','sentiment']]

feedback_df_exploded
# Out:
#                         id                                            content  \
# 0      377380-203583770957  من الاماكن الهاديه الجميله الممتعه في التسوق ت...
# 1      377380-203583770957  من الاماكن الهاديه الجميله الممتعه في التسوق ت...
# 2      377380-203585579625  مساحة خضراء تتنفس فيها الهواء النقي .. المناظر...
# 3      377380-203585579625  مساحة خضراء تتنفس فيها الهواء النقي .. المناظر...
# 4      377380-203585579625  مساحة خضراء تتنفس فيها الهواء النقي .. المناظر...
# ...                    ...                                                ...
# 12926  377380-170059072985  More(Translated by Google) The mosque is curre...
# 12927  377380-168116614508  More(Translated by Google) The best branch of ...
# 12928  377380-170027061275                                         الأكل عادي
# 12929  377380-167887315495                                     سوق كبير وجميل
# 12930  377380-170021789104                                               روعة
#
#                            date language                            title  \
# 0     2021-04-11 06:45:00+00:00      ara  Al Ahsa Mall by Arabian Centres
# 1     2021-04-11 06:45:00+00:00      ara  Al Ahsa Mall by Arabian Centres
# 2     2021-04-11 06:45:00+00:00      ara    King Abdullah Park, Sea front
# 3     2021-04-11 06:45:00+00:00      ara    King Abdullah Park, Sea front
# 4     2021-04-11 06:45:00+00:00      ara    King Abdullah Park, Sea front
# ...                         ...      ...                              ...
# 12926 2021-02-15 00:00:00+00:00      ara                   Jawatha Mosque
# 12927 2021-02-15 00:00:00+00:00      ara        Burger King - Enoc Dareen
# 12928 2021-02-15 00:00:00+00:00      ara                      Güzel Saray
# 12929 2021-02-15 00:00:00+00:00      ara              Riyadh Gallery Mall
# 12930 2021-02-15 00:00:00+00:00      ara      Burger King - Al Safa Plaza
#
#       destination                    offering                   tag  \
# 0         Al Ahsa  Tourism Attractions/ Sites  c07bdfc8hb0r13sa7agg
# 1         Al Ahsa                      Retail  c07bdfc8hb0r13sa7ah0
# 2          Khobar  Tourism Attractions/ Sites  c07bdncbb64t6si78ssg
# 3         Madinah  Tourism Attractions/ Sites  c07bdofepd3oq1r123kg
# 4          Riyadh               Accommodation  c0rquskbb64sdb6ukkq0
# ...           ...                         ...                   ...
# 12926     Al Ahsa                   Religious  c07bdfc8hb0r13sa7amg
# 12927      Dammam             Food & Beverage  c07bdifepd3oq1r122r0
# 12928       Yanbu             Food & Beverage  c07bk44bb64t6si78v80
# 12929      Riyadh                      Retail  c0rqvf8cu1i938rekgn0
# 12930      Dammam             Food & Beverage  c07bdifepd3oq1r122r0
#
#        normalized_rating  actual_rating sentiment
# 0                  100.0            5.0      None
# 1                  100.0            5.0      None
# 2                  100.0            5.0      None
# 3                  100.0            5.0      None
# 4                  100.0            5.0      None
# ...                  ...            ...       ...
# 12926               60.0            3.0      None
# 12927               80.0            4.0      None
# 12928               60.0            3.0      None
# 12929               80.0            4.0      None
# 12930              100.0            5.0      None
#
# [12931 rows x 11 columns]

# %%
#one-hot encoding for 'offering' column
final_df_encoded = pd.get_dummies(feedback_df_exploded, columns=['offering'],dtype=int)
final_df_encoded['sentiment'] = final_df_encoded['sentiment'].fillna('missing')

final_df = final_df_encoded.groupby(
    ['id', 'content', 'date', 'language', 'title', 'normalized_rating', 'actual_rating', 'sentiment'],
    as_index=False
).agg({
    'offering_Accommodation': 'sum',
    'offering_Food & Beverage': 'sum',
    'offering_Retail': 'sum',
    'offering_Tourism Attractions/ Sites': 'sum',
    'destination': list
})

final_df
# Out:
#                        id                                            content  \
# 0     377380-167052110186                          جميل جدن خدمه فاخره مميزه
# 1     377380-167053227344                        مكان جميل في شرما على البحر
# 2     377380-167056314181                                         Good Hotel
# 3     377380-167057432860                 منتجع جميل يحتاج إلى ترتيب وأهتمام
# 4     377380-167058489640                             جيده الاستقبال محترمين
# ...                   ...                                                ...
# 9946  377380-208857650522                                      Nice and good
# 9947  377380-225738358384                                   رائعه وجميله جدا
# 9948  377380-259913223515                   أجمل متنزهات السعودية فعلآ رائعة
# 9949  377380-259913232905                                جمييييله جدا ورائعه
# 9950  377380-259913238900  المنتزه الرئيسي بمدينة الطائف يقصده السكان وال...
#
#                           date language  \
# 0    2021-02-07 00:14:00+00:00      ara
# 1    2021-02-07 00:01:00+00:00      ara
# 2    2021-02-07 01:51:00+00:00      eng
# 3    2021-02-07 00:45:00+00:00      ara
# 4    2021-02-07 02:28:00+00:00      ara
# ...                        ...      ...
# 9946 2021-06-01 12:07:00+00:00      eng
# 9947 2022-10-17 11:16:00+00:00      ara
# 9948 2023-10-03 06:31:00+00:00      ara
# 9949 2023-10-03 02:30:00+00:00      ara
# 9950 2023-10-01 11:28:00+00:00      ara
#
#                                                   title  normalized_rating  \
# 0                           Hotel Raffles Makkah Palace              100.0
# 1                                    HYAT SHARMA RESORT               60.0
# 2                                         Novotel Yanbu               80.0
# 3     منتجع و سبا درة الرياض / Durrat Al Riyadh Reso...               80.0
# 4                                    ديم للغرف الفندقية               60.0
# ...                                                 ...                ...
# 9946                     Burger King - Riyadh Gallery 2              100.0
# 9947                                 Prince Hussam Park              100.0
# 9948                                      Arruddaf Park              100.0
# 9949                                      Arruddaf Park              100.0
# 9950                                      Arruddaf Park              100.0
#
#       actual_rating sentiment  offering_Accommodation  \
# 0               5.0   missing                       1
# 1               3.0   missing                       1
# 2               4.0   missing                       1
# 3               4.0   missing                       1
# 4               3.0   missing                       1
# ...             ...       ...                     ...
# 9946            5.0   missing                       1
# 9947            5.0   missing                       0
# 9948            5.0   missing                       0
# 9949            5.0   missing                       0
# 9950            5.0   missing                       0
#
#       offering_Food & Beverage  offering_Retail  \
# 0                            0                0
# 1                            0                0
# 2                            0                0
# 3                            1                0
# 4                            0                0
# ...                        ...              ...
# 9946                         1                0
# 9947                         0                0
# 9948                         0                0
# 9949                         0                0
# 9950                         0                0
#
#       offering_Tourism Attractions/ Sites       destination
# 0                                       1  [Makkah, Makkah]
# 1                                       0           [Tabuk]
# 2                                       0           [Yanbu]
# 3                                       0  [Riyadh, Riyadh]
# 4                                       0          [Dammam]
# ...                                   ...               ...
# 9946                                    0  [Riyadh, Riyadh]
# 9947                                    1         [Al Baha]
# 9948                                    1            [Taif]
# 9949                                    1            [Taif]
# 9950                                    1            [Taif]
#
# [9951 rows x 13 columns]

# %%
# Converting offering_xxxx column into a 0/1 flag only
cols = ['offering_Accommodation', 'offering_Food & Beverage', 'offering_Retail', 'offering_Tourism Attractions/ Sites']
for col in cols:
    final_df[col] = final_df[col].map(lambda x: 1 if x > 0 else 0)

# %%
# Keeping more than one destination per content is not useful, so we will keep the most common destination for each content
def get_most_common_destination(destinations):
    destination_counts_dict = {}
    for destination in destinations:
        if destination in destination_counts_dict:
            destination_counts_dict[destination] += 1
        else:
            destination_counts_dict[destination] = 1
    return max(destination_counts_dict, key=destination_counts_dict.get)

# Apply the function to the 'destination' column
final_df['destination'] = final_df['destination'].apply(get_most_common_destination)

final_df
# Out:
#                        id                                            content  \
# 0     377380-167052110186                          جميل جدن خدمه فاخره مميزه
# 1     377380-167053227344                        مكان جميل في شرما على البحر
# 2     377380-167056314181                                         Good Hotel
# 3     377380-167057432860                 منتجع جميل يحتاج إلى ترتيب وأهتمام
# 4     377380-167058489640                             جيده الاستقبال محترمين
# ...                   ...                                                ...
# 9946  377380-208857650522                                      Nice and good
# 9947  377380-225738358384                                   رائعه وجميله جدا
# 9948  377380-259913223515                   أجمل متنزهات السعودية فعلآ رائعة
# 9949  377380-259913232905                                جمييييله جدا ورائعه
# 9950  377380-259913238900  المنتزه الرئيسي بمدينة الطائف يقصده السكان وال...
#
#                           date language  \
# 0    2021-02-07 00:14:00+00:00      ara
# 1    2021-02-07 00:01:00+00:00      ara
# 2    2021-02-07 01:51:00+00:00      eng
# 3    2021-02-07 00:45:00+00:00      ara
# 4    2021-02-07 02:28:00+00:00      ara
# ...                        ...      ...
# 9946 2021-06-01 12:07:00+00:00      eng
# 9947 2022-10-17 11:16:00+00:00      ara
# 9948 2023-10-03 06:31:00+00:00      ara
# 9949 2023-10-03 02:30:00+00:00      ara
# 9950 2023-10-01 11:28:00+00:00      ara
#
#                                                   title  normalized_rating  \
# 0                           Hotel Raffles Makkah Palace              100.0
# 1                                    HYAT SHARMA RESORT               60.0
# 2                                         Novotel Yanbu               80.0
# 3     منتجع و سبا درة الرياض / Durrat Al Riyadh Reso...               80.0
# 4                                    ديم للغرف الفندقية               60.0
# ...                                                 ...                ...
# 9946                     Burger King - Riyadh Gallery 2              100.0
# 9947                                 Prince Hussam Park              100.0
# 9948                                      Arruddaf Park              100.0
# 9949                                      Arruddaf Park              100.0
# 9950                                      Arruddaf Park              100.0
#
#       actual_rating sentiment  offering_Accommodation  \
# 0               5.0   missing                       1
# 1               3.0   missing                       1
# 2               4.0   missing                       1
# 3               4.0   missing                       1
# 4               3.0   missing                       1
# ...             ...       ...                     ...
# 9946            5.0   missing                       1
# 9947            5.0   missing                       0
# 9948            5.0   missing                       0
# 9949            5.0   missing                       0
# 9950            5.0   missing                       0
#
#       offering_Food & Beverage  offering_Retail  \
# 0                            0                0
# 1                            0                0
# 2                            0                0
# 3                            1                0
# 4                            0                0
# ...                        ...              ...
# 9946                         1                0
# 9947                         0                0
# 9948                         0                0
# 9949                         0                0
# 9950                         0                0
#
#       offering_Tourism Attractions/ Sites destination
# 0                                       1      Makkah
# 1                                       0       Tabuk
# 2                                       0       Yanbu
# 3                                       0      Riyadh
# 4                                       0      Dammam
# ...                                   ...         ...
# 9946                                    0      Riyadh
# 9947                                    1     Al Baha
# 9948                                    1        Taif
# 9949                                    1        Taif
# 9950                                    1        Taif
#
# [9951 rows x 13 columns]

# %%
#looking into range of ratings, and check for errors
final_df.groupby(['actual_rating','normalized_rating']).size().reset_index(name='counts').sort_values(by='actual_rating',ascending=False)
# Out:
#     actual_rating  normalized_rating  counts
# 13           10.0              100.0       6
# 12            8.0               80.0       7
# 11            6.0               60.0       4
# 10            5.0              100.0    6002
# 9             4.5               90.0       7
# 7             4.0               40.0       2
# 8             4.0               80.0    1728
# 6             3.5               70.0       5
# 5             3.0               60.0    1088
# 4             2.5               50.0       2
# 2             2.0               20.0       1
# 3             2.0               40.0     367
# 1             1.0               20.0     731
# 0             0.5               10.0       1

# %%
#Fix normalization for ratings with 0/5 as 0 and 5/5 as 100 and any RATING >5 as 100
final_df['normalized_rating'] = final_df['actual_rating'].apply(lambda x: 100 if x > 5 else x * 20)

# %%
final_df.groupby(['actual_rating','normalized_rating']).size().reset_index(name='counts').sort_values(by='actual_rating',ascending=False)
# Out:
#     actual_rating  normalized_rating  counts
# 11           10.0              100.0       6
# 10            8.0              100.0       7
# 9             6.0              100.0       4
# 8             5.0              100.0    6002
# 7             4.5               90.0       7
# 6             4.0               80.0    1730
# 5             3.5               70.0       5
# 4             3.0               60.0    1088
# 3             2.5               50.0       2
# 2             2.0               40.0     368
# 1             1.0               20.0     731
# 0             0.5               10.0       1

# %%
#Adding a sentiment to each row - METHOD 1  (Lexicon Based Approach)

from textblob import TextBlob
def get_sentiment(text):
    polarity = TextBlob(str(text)).sentiment.polarity
    if polarity > 0.1:
        return 'positive'
    elif polarity < -0.1:
        return 'negative'
    else:
        return 'neutral'

# Apply sentiment analysis for reviews
final_df['sentiment_lexicon'] = final_df['content'].apply(get_sentiment)
final_df.drop('sentiment', axis=1, inplace=True)

# %%
#Adding a sentiment to each row - METHOD 2  
#Task-Specific Large Language Model : XLM-RoBERTa pre-trained LLM model + Neural Network Classification model

#Model used is twitter-XLM-RoBERTa-base for Sentiment Analysis (https://huggingface.co/cardiffnlp/twitter-xlm-roberta-base-sentiment)

#Model is integrated into "tweetnlp" library (https://github.com/cardiffnlp/tweetnlp)
import tweetnlp 

# Load a multilingual sentiment analysis pipeline 
# XLM-RoBERTa converts each text into a embedding/vector then Neural Network layer classifies as Postive/Negative/Neutral

model = tweetnlp.load_model('sentiment',multilingual=True)  

# run the entire column in one call, in batches
texts = final_df['content'].astype(str).tolist()
results = model.predict(texts) 

# # extract labels and assign back to the DataFrame
final_df['sentiment_LLM'] = [r['label'] for r in results]
# Out:
# 2026-02-16 01:53:04,269	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.8.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2026-02-16 01:53:04,506	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.8.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# c:\Users\alikr\anaconda3\Lib\site-packages\transformers\models\auto\configuration_auto.py:957: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# c:\Users\alikr\anaconda3\Lib\site-packages\transformers\models\auto\tokenization_auto.py:785: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# c:\Users\alikr\anaconda3\Lib\site-packages\transformers\models\auto\auto_factory.py:469: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(

# %%
pip install -U ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\Users\alikr\anaconda3\Lib\site-packages (7.8.1)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\Users\alikr\anaconda3\Lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\Users\alikr\anaconda3\Lib\site-packages (from ipywidgets) (8.25.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\Users\alikr\anaconda3\Lib\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in c:\Users\alikr\anaconda3\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\Users\alikr\anaconda3\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\Users\alikr\anaconda3\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\Users\alikr\anaconda3\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\Users\alikr\anaconda3\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\Users\alikr\anaconda3\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\Users\alikr\anaconda3\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: wcwidth in c:\Users\alikr\anaconda3\Lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\Users\alikr\anaconda3\Lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: executing in c:\Users\alikr\anaconda3\Lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\Users\alikr\anaconda3\Lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\Users\alikr\anaconda3\Lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in c:\Users\alikr\anaconda3\Lib\site-packages (from asttokens->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------------- 914.9/914.9 kB ?  0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 60.4 MB/s  0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
#
#   Attempting uninstall: widgetsnbextension
#
#     Found existing installation: widgetsnbextension 3.6.6
#
#     Uninstalling widgetsnbextension-3.6.6:
#
#       Successfully uninstalled widgetsnbextension-3.6.6
#
#   Attempting uninstall: jupyterlab_widgets
#
#     Found existing installation: jupyterlab-widgets 1.0.0
#
#     Uninstalling jupyterlab-widgets-1.0.0:
#
#       Successfully uninstalled jupyterlab-widgets-1.0.0
#
#   Attempting uninstall: ipywidgets
#
#     Found existing installation: ipywidgets 7.8.1
#
#     Uninstalling ipywidgets-7.8.1:
#
#       Successfully uninstalled ipywidgets-7.8.1
#
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    ---------------------------------------- 3/3 [ipywidgets]
#
# Successfully installed ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 widgetsnbextension-4.0.15
# Note: you may need to restart the kernel to use updated packages.

# %%
# Comparing the two methods for sentiment analysis (Lexicon vs LLM) 
# For English reviews only (since Lexicon only works for English)
eng_df = final_df[final_df['language'] == 'eng']

sent_counts = (
    pd.DataFrame({
        'sentiment_lexicon': eng_df['sentiment_lexicon'].value_counts(),
        'sentiment_LLM': eng_df['sentiment_LLM'].value_counts()
    })
    .fillna(0)
    .astype(int)
)

plot_df = sent_counts.reset_index().melt(id_vars='index', var_name='method', value_name='count')
plot_df.rename(columns={'index': 'sentiment'}, inplace=True)

plt.figure(figsize=(8, 4))
ax = sns.barplot(data=plot_df, x='sentiment', y='count', hue='method')
plt.title('Sentiment Counts (English Only): Lexicon vs LLM')
plt.xlabel('Sentiment')
plt.ylabel('Count')

for container in ax.containers:
    ax.bar_label(container, fmt='%d', padding=2)

plt.tight_layout()
plt.show()

# %%
#Manually comparison when 2 mehods disagree for English reviews only 
final_df[(final_df['language'] == 'eng') & (final_df['sentiment_LLM'] != final_df['sentiment_lexicon'])][['content', 'sentiment_LLM', 'sentiment_lexicon']].head(20)
# Out:
#                                                content sentiment_LLM  \
# 6    Nice hotel. Clean. I staryed in a regular room...       neutral
# 61   Nice elegant hotel and good service but rooms ...       neutral
# 64                                           It was ok       neutral
# 91   Why deffirent price compare from jeddah. Here ...      negative
# 120  Balad is always best for shopping in the heart...      negative
# 218  Available varieties of fish u can buy at cheap...       neutral
# 228                           Madina jano Dil se pyara      positive
# 229                    Not even stars to rate the Uhud      negative
# 251  Masha Allah..... no words are inough to Expres...      positive
# 283  When I performing Umrah one old picture other ...       neutral
# 293  More(Translated by Google) Muslim kiss and sme...       neutral
# 296                Wow, world 1st ranked review place,      positive
# 299  World peaceful place where every Muslim wants ...       neutral
# 313  Hopefully my stay will be long-term. Stayed in...      positive
# 336  Food was alright. The chicken in the pasta was...      positive
# 338  Better to buy tickets to Santorini and visit O...       neutral
# 387       Need to improve its ambience overall ok mall      negative
# 400  They have apple bee's we celebrated our weddin...       neutral
# 409  View is good, furniture is nice. Recpition org...      negative
# 425  Lazy housekeeping .. no car parking service .....      negative
#
#     sentiment_lexicon
# 6            positive
# 61           positive
# 64           positive
# 91           positive
# 120          positive
# 218          positive
# 228           neutral
# 229           neutral
# 251           neutral
# 283          positive
# 293          positive
# 296           neutral
# 299          positive
# 313           neutral
# 336           neutral
# 338          positive
# 387          positive
# 400          positive
# 409          positive
# 425          positive

# %% [markdown]
# #### Part 2: Text Cleaning & NLP Analysis

# %%
#Some content has both arabic (original) and english (translation) text both
final_df[final_df.content.str.contains('(Translated by Google)')]
# Out:
# C:\Users\alikr\AppData\Local\Temp\ipykernel_1984\1423563141.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   final_df[final_df.content.str.contains('(Translated by Google)')]
#                        id                                            content  \
# 33    377380-167138153854  More(Translated by Google) A beautiful small g...
# 34    377380-167138153875  More(Translated by Google) The idea deserves f...
# 79    377380-167155590734  More(Translated by Google) God honors grace fo...
# 80    377380-167155596507  More(Translated by Google) A very nice restaur...
# 244   377380-167200689785  More(Translated by Google) He, may God’s praye...
# ...                   ...                                                ...
# 3982  377380-172533523081  More(Translated by Google) Awesome organizatio...
# 3983  377380-172533523170  More(Translated by Google) The staff at the mo...
# 3996  377380-172697737880  More(Translated by Google) The visit took plac...
# 3997  377380-172697746022  More(Translated by Google) The place is nice a...
# 3998  377380-172697749038  More(Translated by Google) A restaurant locate...
#
#                           date language                        title  \
# 33   2021-02-07 00:00:00+00:00      ara            WORLD SIGHTS PARK
# 34   2021-02-07 00:00:00+00:00      ara            WORLD SIGHTS PARK
# 79   2021-02-07 00:00:00+00:00      ara                Noor Al Hanaa
# 80   2021-02-07 00:00:00+00:00      eng  Oah Yamal Restaurant Dammam
# 244  2021-02-07 00:00:00+00:00      eng                  Masjed Quba
# ...                        ...      ...                          ...
# 3982 2021-04-11 07:20:00+00:00      eng   Dhul Hulaifah Miqat Mosque
# 3983 2021-04-11 07:21:00+00:00      eng   Dhul Hulaifah Miqat Mosque
# 3996 2021-04-11 07:54:00+00:00      ara       Taya Restaurant Khobar
# 3997 2021-04-11 07:46:00+00:00      eng       Taya Restaurant Khobar
# 3998 2021-04-11 07:47:00+00:00      ara       Taya Restaurant Khobar
#
#       normalized_rating  actual_rating  offering_Accommodation  \
# 33                 80.0            4.0                       0
# 34                 80.0            4.0                       0
# 79                 20.0            1.0                       1
# 80                100.0            5.0                       0
# 244               100.0            5.0                       0
# ...                 ...            ...                     ...
# 3982              100.0            5.0                       0
# 3983               80.0            4.0                       0
# 3996               80.0            4.0                       0
# 3997               80.0            4.0                       0
# 3998               40.0            2.0                       0
#
#       offering_Food & Beverage  offering_Retail  \
# 33                           0                0
# 34                           0                0
# 79                           0                0
# 80                           1                0
# 244                          0                0
# ...                        ...              ...
# 3982                         0                0
# 3983                         0                0
# 3996                         1                0
# 3997                         1                0
# 3998                         1                0
#
#       offering_Tourism Attractions/ Sites destination sentiment_lexicon  \
# 33                                      1      Riyadh          positive
# 34                                      1      Riyadh          positive
# 79                                      0      Riyadh           neutral
# 80                                      0      Dammam          positive
# 244                                     0     Madinah          positive
# ...                                   ...         ...               ...
# 3982                                    0     Madinah          positive
# 3983                                    0     Madinah          positive
# 3996                                    0      Khobar          positive
# 3997                                    0      Khobar          positive
# 3998                                    0      Khobar          positive
#
#      sentiment_LLM
# 33         neutral
# 34        negative
# 79        positive
# 80        positive
# 244       positive
# ...            ...
# 3982      positive
# 3983       neutral
# 3996       neutral
# 3997      positive
# 3998      positive
#
# [822 rows x 14 columns]

# %%
#Some content has both arabic (original) and english (translation) text both, so we keep english version only and make sure 'language' is set to 'eng'
def clean_content_and_language(row):
    content = row['content']
    language = row['language']
    if '(Translated by Google)' in content:
        content = content.split('(Translated by Google)')[-1]
        content = content.split('(Original)')[0]
        language = 'eng'
    return pd.Series([content, language])

final_df[['content', 'language']] = final_df.apply(clean_content_and_language, axis=1)

final_df
# Out:
#                        id                                            content  \
# 0     377380-167052110186                          جميل جدن خدمه فاخره مميزه
# 1     377380-167053227344                        مكان جميل في شرما على البحر
# 2     377380-167056314181                                         Good Hotel
# 3     377380-167057432860                 منتجع جميل يحتاج إلى ترتيب وأهتمام
# 4     377380-167058489640                             جيده الاستقبال محترمين
# ...                   ...                                                ...
# 9946  377380-208857650522                                      Nice and good
# 9947  377380-225738358384                                   رائعه وجميله جدا
# 9948  377380-259913223515                   أجمل متنزهات السعودية فعلآ رائعة
# 9949  377380-259913232905                                جمييييله جدا ورائعه
# 9950  377380-259913238900  المنتزه الرئيسي بمدينة الطائف يقصده السكان وال...
#
#                           date language  \
# 0    2021-02-07 00:14:00+00:00      ara
# 1    2021-02-07 00:01:00+00:00      ara
# 2    2021-02-07 01:51:00+00:00      eng
# 3    2021-02-07 00:45:00+00:00      ara
# 4    2021-02-07 02:28:00+00:00      ara
# ...                        ...      ...
# 9946 2021-06-01 12:07:00+00:00      eng
# 9947 2022-10-17 11:16:00+00:00      ara
# 9948 2023-10-03 06:31:00+00:00      ara
# 9949 2023-10-03 02:30:00+00:00      ara
# 9950 2023-10-01 11:28:00+00:00      ara
#
#                                                   title  normalized_rating  \
# 0                           Hotel Raffles Makkah Palace              100.0
# 1                                    HYAT SHARMA RESORT               60.0
# 2                                         Novotel Yanbu               80.0
# 3     منتجع و سبا درة الرياض / Durrat Al Riyadh Reso...               80.0
# 4                                    ديم للغرف الفندقية               60.0
# ...                                                 ...                ...
# 9946                     Burger King - Riyadh Gallery 2              100.0
# 9947                                 Prince Hussam Park              100.0
# 9948                                      Arruddaf Park              100.0
# 9949                                      Arruddaf Park              100.0
# 9950                                      Arruddaf Park              100.0
#
#       actual_rating  offering_Accommodation  offering_Food & Beverage  \
# 0               5.0                       1                         0
# 1               3.0                       1                         0
# 2               4.0                       1                         0
# 3               4.0                       1                         1
# 4               3.0                       1                         0
# ...             ...                     ...                       ...
# 9946            5.0                       1                         1
# 9947            5.0                       0                         0
# 9948            5.0                       0                         0
# 9949            5.0                       0                         0
# 9950            5.0                       0                         0
#
#       offering_Retail  offering_Tourism Attractions/ Sites destination  \
# 0                   0                                    1      Makkah
# 1                   0                                    0       Tabuk
# 2                   0                                    0       Yanbu
# 3                   0                                    0      Riyadh
# 4                   0                                    0      Dammam
# ...               ...                                  ...         ...
# 9946                0                                    0      Riyadh
# 9947                0                                    1     Al Baha
# 9948                0                                    1        Taif
# 9949                0                                    1        Taif
# 9950                0                                    1        Taif
#
#      sentiment_lexicon sentiment_LLM
# 0              neutral      positive
# 1              neutral      positive
# 2             positive      positive
# 3              neutral      positive
# 4              neutral      positive
# ...                ...           ...
# 9946          positive      positive
# 9947           neutral      positive
# 9948           neutral      positive
# 9949           neutral      positive
# 9950           neutral       neutral
#
# [9951 rows x 14 columns]

# %%
#Check if language is correctly identified 
import re

def detect_language_rule_based(text):
    text = str(text)
    has_english = re.search(r'[a-zA-Z]', text) is not None
    has_arabic = re.search(r'[\u0600-\u06FF]', text) is not None
    if has_english and has_arabic:
        return 'mixed'
    elif has_english:
        return 'eng'
    elif has_arabic:
        return 'ara'
    else:
        return 'unknown'

final_df['language_2'] = final_df['content'].apply(detect_language_rule_based)

mismatched_lang = final_df[final_df['language'] != final_df['language_2']]
mismatched_lang[['id','content','language', 'language_2']].sort_values(by='language_2')
# Out:
#                        id                                            content  \
# 3366  377380-169028410235                              موقعه المطل على الحرم
# 102   377380-167167970137                                               ‏تاز
# 1153  377380-167507833940                                     التفاصيل جميلة
# 998   377380-167453509020                             عطوني ليلة مجانيه ☹️❤️
# 3414  377380-169484640565                               نضيف لكن السعر مرتفع
# ...                   ...                                                ...
# 4486  377380-176505233720  حسب الصور التقييم النهائي بعد زيارتي اليوم",nu...
# 4487  377380-176505233723  لا بأس وياليت يهتمون بالنظافة .",null,"لا بأس ...
# 4488  377380-176520254038  تجربه جيده ولكن يعيبه ارتفاع السعر قليلاً",nul...
# 7919  377380-203586853320                                                  🧐
# 2490  377380-167730611585                                              50 50
#
#      language language_2
# 3366      eng        ara
# 102       eng        ara
# 1153      eng        ara
# 998       eng        ara
# 3414      eng        ara
# ...       ...        ...
# 4486      ara      mixed
# 4487      ara      mixed
# 4488      ara      mixed
# 7919      eng    unknown
# 2490      eng    unknown
#
# [191 rows x 4 columns]

# %%
#There are few rows that are misidentified
mismatched_lang.groupby('language_2')['id'].count()
# Out:
# language_2
# ara          8
# eng         28
# mixed      153
# unknown      2
# Name: id, dtype: int64

# %%
#update the language column where language_2 is 'eng' or 'ara' only
final_df.loc[final_df['language_2'].isin(['eng', 'ara']), 'language'] = final_df['language_2']
final_df.drop('language_2', axis=1, inplace=True)

# %%
# Text Cleaning
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from camel_tools.tokenizers.word import simple_word_tokenize
from camel_tools.utils.dediac import dediac_ar

nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)

# Init language resources
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
arabic_stopwords = set(stopwords.words('arabic'))

# text cleaner fxn
def clean_text(text, language=None):
    text = '' if text is None else str(text)
    # If language not provided, guess by presence of Arabic chars
    if language is None:
        language = 'ara' if re.search(r'[\u0600-\u06FF]', text) else 'eng'

    if language == 'eng':
        # Remove non-letter characters (punctuation/numbers)
        t = re.sub(r'[^a-zA-Z\s]', '', text)
        # Normalize case
        t = t.lower()
        # Tokenize and remove English stopwords
        words = [w for w in t.split() if w and w not in stop_words]
        # Lemmatize tokens
        words = [lemmatizer.lemmatize(w) for w in words]
        # Return cleaned text
        return ' '.join(words)

    if language == 'ara':
        # Remove diacritics
        t = dediac_ar(text)
        # Keep Arabic letters and spaces only
        t = re.sub(r'[^\u0600-\u06FF\s]', '', t)
        # Tokenize Arabic text
        words = simple_word_tokenize(t)
        # Remove Arabic stopwords and empty tokens
        words = [w for w in words if w and w not in arabic_stopwords]
        # Return cleaned Arabic text
        return ' '.join(words)

    # fallback -> return original string
    return text

# Apply to dataframe
final_df['clean_content'] = final_df.apply(lambda row: clean_text(row['content'], row.get('language')), axis=1)

# %%
final_df[['content', 'clean_content']]
# Out:
#                                                 content  \
# 0                             جميل جدن خدمه فاخره مميزه
# 1                           مكان جميل في شرما على البحر
# 2                                            Good Hotel
# 3                    منتجع جميل يحتاج إلى ترتيب وأهتمام
# 4                                جيده الاستقبال محترمين
# ...                                                 ...
# 9946                                      Nice and good
# 9947                                   رائعه وجميله جدا
# 9948                   أجمل متنزهات السعودية فعلآ رائعة
# 9949                                جمييييله جدا ورائعه
# 9950  المنتزه الرئيسي بمدينة الطائف يقصده السكان وال...
#
#                                           clean_content
# 0                             جميل جدن خدمه فاخره مميزه
# 1                                  مكان جميل شرما البحر
# 2                                            good hotel
# 3                        منتجع جميل يحتاج ترتيب وأهتمام
# 4                                جيده الاستقبال محترمين
# ...                                                 ...
# 9946                                          nice good
# 9947                                   رائعه وجميله جدا
# 9948                   أجمل متنزهات السعودية فعلآ رائعة
# 9949                                جمييييله جدا ورائعه
# 9950  المنتزه الرئيسي بمدينة الطائف يقصده السكان وال...
#
# [9951 rows x 2 columns]

# %%
#remove uncleaned content column as we have the cleaned version now
final_df.drop('content', inplace=True, axis=1)

# %%
#Text Analysis (Common Keywords) - Frequency Based Approach (Term Frequency-Inverse Document Frequency: TF-IDF)

from sklearn.feature_extraction.text import TfidfVectorizer

# Compute TF-IDF
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(final_df['clean_content'].fillna(''))
feature_names = vectorizer.get_feature_names_out()
dense = tfidf_matrix.todense()
denselist = dense.tolist()
df_tfidf = pd.DataFrame(denselist, columns=feature_names)
common_keywords = df_tfidf.sum().nlargest(20)
print(common_keywords)
# Out:
# جميل         368.991688
# جدا          350.616022
# ممتاز        272.946864
# رائع         203.544996
# مكان         195.512160
# place        175.862023
# good         173.847159
# جيد          136.485058
# nice         130.471749
# الله          97.965005
# فندق          92.079475
# المكان        81.779579
# beautiful     71.846030
# جميله         70.695729
# جميلة         65.123305
# best          63.743942
# نظيف          62.794382
# great         59.966767
# ونظيف         56.587229
# excellent     56.132496
# dtype: float64

# %%
#Represent common words in a word cloud viz

import os, requests, arabic_reshaper
from bidi.algorithm import get_display
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# font: try Windows, else download Amiri into ./fonts
cands=[r"C:\Windows\Fonts\NotoNaskhArabic-Regular.ttf", r"C:\Windows\Fonts\Amiri-Regular.ttf", r"C:\Windows\Fonts\Tahoma.ttf"]
font_path=next((p for p in cands if os.path.exists(p)), None)
if not font_path:
    os.makedirs("fonts", exist_ok=True)
    font_path="fonts/Amiri-Regular.ttf"
    if not os.path.exists(font_path):
        r=requests.get("https://github.com/alif-type/amiri/raw/master/Amiri-Regular.ttf", timeout=30); r.raise_for_status()
        open(font_path,"wb").write(r.content)

# build freqs from common_keywords else Arabic cleaned text
freqs={}
if 'common_keywords' in globals() and len(common_keywords):
    items=common_keywords.items()
else:
    texts=final_df.loc[final_df['language']=='ara','clean_content'].dropna().tolist()
    items=((t,1) for t in " ".join(texts).split())

for token,score in items:
    tok=get_display(arabic_reshaper.reshape(str(token)))
    freqs[tok]=freqs.get(tok,0)+float(score)

if not freqs: raise ValueError("No Arabic tokens found")

wc=WordCloud(font_path=font_path, background_color="white", width=800, height=400).generate_from_frequencies(freqs)
plt.figure(figsize=(8,4))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#Text Analysis (Themes)  - METHOD 1 Topic Modeling with LDA (Classic Probabilistic Approach)

from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# Prepare the text data (replace None with empty string)
texts = final_df['clean_content'].fillna('')

# Vectorize the text
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts)

# Fit LDA model
lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(X)

# Show n top words for each topic
n=15
feature_names = vectorizer.get_feature_names_out()
for topic_idx, topic in enumerate(lda.components_):
    print(f"Topic #{topic_idx+1}: " + ", ".join([feature_names[i] for i in topic.argsort()[:-n:-1]]))
# Out:
# Topic #1: جدا, جميل, مكان, الله, ممتاز, فندق, المكان, الفندق, رائع, جيد, نظيف, الاستقبال, يوجد, ونظيف
# Topic #2: place, good, nice, beautiful, one, best, restaurant, food, great, visit, service, family, excellent, park
# Topic #3: ممتاز, رائع, god, mosque, جميلة, may, prayer, حديقة, peace, جدا, تحتاج, جميله, oh, upon
# Topic #4: افضل, الرياض, سوق, يوجد, مكان, مول, يحتاج, أجمل, جميلة, او, جيده, حديقة, المملكة, شي
# Topic #5: جميله, شي, المكان, قلعة, اللي, اجمل, مارد, الفندق, علي, القلعة, بقاع, الأرض, نصيف, الملك

# %%
# Create a mapping dictionary after reviewing the keywords for each topic
topic_to_theme = {
    1: "Accommodation & Positive Venue Experience",
    2: "Food & Dining / Restaurants",
    3: "Religious / Spiritual & Tranquil Sites",
    4: "City Amenities & Shopping (Riyadh-focused)",
    5: "Attractions & Scenic / Heritage Sites"
}

#Mapping topic with hihgets probability for each review
doc_topic_dist = lda.transform(X)

# Get the most probable topic 
most_probable_topic = np.argmax(doc_topic_dist, axis=1) +1
final_df['lda_topic'] = most_probable_topic

#Mapping the most probable topic to themes
final_df['theme_LDA'] = final_df['lda_topic'].map(topic_to_theme)
final_df.drop('lda_topic', axis=1, inplace=True)

final_df
# Out:
#                        id                      date language  \
# 0     377380-167052110186 2021-02-07 00:14:00+00:00      ara
# 1     377380-167053227344 2021-02-07 00:01:00+00:00      ara
# 2     377380-167056314181 2021-02-07 01:51:00+00:00      eng
# 3     377380-167057432860 2021-02-07 00:45:00+00:00      ara
# 4     377380-167058489640 2021-02-07 02:28:00+00:00      ara
# ...                   ...                       ...      ...
# 9946  377380-208857650522 2021-06-01 12:07:00+00:00      eng
# 9947  377380-225738358384 2022-10-17 11:16:00+00:00      ara
# 9948  377380-259913223515 2023-10-03 06:31:00+00:00      ara
# 9949  377380-259913232905 2023-10-03 02:30:00+00:00      ara
# 9950  377380-259913238900 2023-10-01 11:28:00+00:00      ara
#
#                                                   title  normalized_rating  \
# 0                           Hotel Raffles Makkah Palace              100.0
# 1                                    HYAT SHARMA RESORT               60.0
# 2                                         Novotel Yanbu               80.0
# 3     منتجع و سبا درة الرياض / Durrat Al Riyadh Reso...               80.0
# 4                                    ديم للغرف الفندقية               60.0
# ...                                                 ...                ...
# 9946                     Burger King - Riyadh Gallery 2              100.0
# 9947                                 Prince Hussam Park              100.0
# 9948                                      Arruddaf Park              100.0
# 9949                                      Arruddaf Park              100.0
# 9950                                      Arruddaf Park              100.0
#
#       actual_rating  offering_Accommodation  offering_Food & Beverage  \
# 0               5.0                       1                         0
# 1               3.0                       1                         0
# 2               4.0                       1                         0
# 3               4.0                       1                         1
# 4               3.0                       1                         0
# ...             ...                     ...                       ...
# 9946            5.0                       1                         1
# 9947            5.0                       0                         0
# 9948            5.0                       0                         0
# 9949            5.0                       0                         0
# 9950            5.0                       0                         0
#
#       offering_Retail  offering_Tourism Attractions/ Sites destination  \
# 0                   0                                    1      Makkah
# 1                   0                                    0       Tabuk
# 2                   0                                    0       Yanbu
# 3                   0                                    0      Riyadh
# 4                   0                                    0      Dammam
# ...               ...                                  ...         ...
# 9946                0                                    0      Riyadh
# 9947                0                                    1     Al Baha
# 9948                0                                    1        Taif
# 9949                0                                    1        Taif
# 9950                0                                    1        Taif
#
#      sentiment_lexicon sentiment_LLM  \
# 0              neutral      positive
# 1              neutral      positive
# 2             positive      positive
# 3              neutral      positive
# 4              neutral      positive
# ...                ...           ...
# 9946          positive      positive
# 9947           neutral      positive
# 9948           neutral      positive
# 9949           neutral      positive
# 9950           neutral       neutral
#
#                                           clean_content  \
# 0                             جميل جدن خدمه فاخره مميزه
# 1                                  مكان جميل شرما البحر
# 2                                            good hotel
# 3                        منتجع جميل يحتاج ترتيب وأهتمام
# 4                                جيده الاستقبال محترمين
# ...                                                 ...
# 9946                                          nice good
# 9947                                   رائعه وجميله جدا
# 9948                   أجمل متنزهات السعودية فعلآ رائعة
# 9949                                جمييييله جدا ورائعه
# 9950  المنتزه الرئيسي بمدينة الطائف يقصده السكان وال...
#
#                                       theme_LDA
# 0     Accommodation & Positive Venue Experience
# 1     Accommodation & Positive Venue Experience
# 2                   Food & Dining / Restaurants
# 3     Accommodation & Positive Venue Experience
# 4     Accommodation & Positive Venue Experience
# ...                                         ...
# 9946                Food & Dining / Restaurants
# 9947  Accommodation & Positive Venue Experience
# 9948      Attractions & Scenic / Heritage Sites
# 9949  Accommodation & Positive Venue Experience
# 9950     Religious / Spiritual & Tranquil Sites
#
# [9951 rows x 15 columns]

# %%
#Text Analysis (Themes)  - METHOD 2 
# Using Ensemble Model *BERTopic* (LLM + Clustering + Keyword Extraction)
#BERTopic: 
# (1) Use BERT pre-trained LLM model for embedding +
# (2) Clustering algorithm on embeddings via HDBSCAN + 
# (3) Keyword Extraction via TF-IDF for each cluster (top 10 keywords per topic base on TF-IDF score)

from bertopic import BERTopic
from hdbscan import HDBSCAN

# Prepare your review texts
texts = final_df['clean_content'].astype(str).tolist()

# Create and fit BERTopic model (multilingual embeddings)

hdbscan_model = HDBSCAN(min_cluster_size=20, metric='euclidean', prediction_data=True)
topic_model = BERTopic(hdbscan_model=hdbscan_model, top_n_words=10, language="multilingual",nr_topics=20)

topics, probs = topic_model.fit_transform(texts)

# View topics and their keywords (Default is top 10 keywords per topic base on TF-IDF score)
topic_info = topic_model.get_topic_info()
topic_info[['Topic','Name','Count','Representation']]
# Out:
#     Topic                              Name  Count  \
# 0      -1            -1_place_جدا_مكان_جميل   2380
# 1       0             0_ممتاز_جدا_جميل_رائع   1960
# 2       1            1_مكان_جميل_place_park   1308
# 3       2           2_فندق_الفندق_hotel_جدا   1112
# 4       3          3_الله_الفندق_الرياض_جدا    840
# 5       4  4_restaurant_food_delicious_مطعم    733
# 6       5             5_mosque_god_الله_may    404
# 7       6        6_mall_سوق_market_shopping    329
# 8       7                7_مغلق_سيء_سيئ_bad    252
# 9       8           8_هادئ_place_relax_مكان    124
# 10      9     9_family_place_للعائلات_عائلي    103
# 11     10         10_يحتاج_تحتاج_اكثر_تجديد     76
# 12     11        11_fish_السمك_price_market     75
# 13     12   12_المياه_الحمامات_دورات_toilet     64
# 14     13     13_parking_السيارات_car_مواقف     43
# 15     14        14_cinema_movie_hall_sound     41
# 16     15         15_love_loved_shada_العشق     36
# 17     16       16_الليل_night_time_الإضاءة     26
# 18     17       17_الطائرة_طائرة_حطام_خلابه     23
# 19     18         18_معلم_ومعلم_سياحي_معالم     22
#
#                                        Representation
# 0   [place, جدا, مكان, جميل, المكان, good, beautif...
# 1   [ممتاز, جدا, جميل, رائع, جيد, good, جميله, جمي...
# 2   [مكان, جميل, place, park, حديقة, جدا, منتزه, b...
# 3   [فندق, الفندق, hotel, جدا, الغرف, نظيف, جميل, ...
# 4   [الله, الفندق, الرياض, جدا, المكان, اللي, او, ...
# 5   [restaurant, food, delicious, مطعم, لذيذ, best...
# 6   [mosque, god, الله, may, prayer, house, prophe...
# 7   [mall, سوق, market, shopping, مبالغ, الاسعار, ...
# 8   [مغلق, سيء, سيئ, bad, جدا, سيئه, سيئة, المكان,...
# 9   [هادئ, place, relax, مكان, quiet, calm, هادئة,...
# 10  [family, place, للعائلات, عائلي, good, للعائله...
# 11  [يحتاج, تحتاج, اكثر, تجديد, تطوير, الى, اهتمام...
# 12  [fish, السمك, price, market, fresh, الأسماك, ا...
# 13  [المياه, الحمامات, دورات, toilet, مياه, وصخ, b...
# 14  [parking, السيارات, car, مواقف, get, cable, tr...
# 15  [cinema, movie, hall, sound, screen, theatre, ...
# 16  [love, loved, shada, العشق, suite, mom, عشقي, ...
# 17  [الليل, night, time, الإضاءة, evening, fentest...
# 18  [الطائرة, طائرة, حطام, خلابه, plane, لحطام, ال...
# 19  [معلم, ومعلم, سياحي, معالم, حضاري, الاحساء, يس...

# %%
#Topic "-1" which represents outliers is a common topic. (2280 counts)
# We will reassign these outliers to the nearest topic based on their distributional similarity to other topics.

# Reassign outliers reviews (topic -1) to nearest topic
topics = topic_model.reduce_outliers(texts, topics, strategy="distributions")
topic_model.update_topics(docs=texts, topics=topics)

final_df['topic_BERT'] = topics

# View topics and their keywords (Default is top 10 keywords per topic base on TF-IDF)
topic_info = topic_model.get_topic_info()
topic_info[['Topic','Name','Count','Representation']]
# Out:
# 2026-02-16 02:05:33,021 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#     Topic                                              Name  Count  \
# 0      -1  -1_روووعة_زححححححححممممممممممممممه_اجربها_الاجمل     30
# 1       0                             0_جدا_ممتاز_جميل_رائع   2341
# 2       1                            1_مكان_جميل_park_place   1678
# 3       2                           2_فندق_الفندق_جدا_hotel   1262
# 4       3                       3_الله_المكان_الرياض_الفندق   1162
# 5       4                  4_restaurant_food_delicious_good    902
# 6       5                             5_mosque_god_الله_may    473
# 7       6                        6_mall_سوق_market_shopping    460
# 8       7                               7_مغلق_سيء_جدا_سيئه    368
# 9       8                   8_place_هادئ_beautiful_peaceful    213
# 10      9                      9_family_place_good_للعائلات    201
# 11     10                         10_يحتاج_تحتاج_الى_اهتمام    198
# 12     11                        11_fish_price_السمك_market    102
# 13     12                     12_المياه_دورات_مياه_الحمامات    127
# 14     13                          13_car_parking_get_drive    101
# 15     14                          14_cinema_movie_hall_غني     98
# 16     15                    15_love_loved_falsefalse_place     60
# 17     16                        16_الليل_view_time_evening     54
# 18     17                       17_روعة_أجواء_خلابه_الطائرة     68
# 19     18                             18_معلم_بأس_سياحي_احب     53
#
#                                        Representation
# 0   [روووعة, زححححححححممممممممممممممه, اجربها, الا...
# 1   [جدا, ممتاز, جميل, رائع, جيد, جميله, good, جمي...
# 2   [مكان, جميل, park, place, حديقة, جدا, منتزه, v...
# 3   [فندق, الفندق, جدا, hotel, نظيف, الغرف, ونظيف,...
# 4   [الله, المكان, الرياض, الفندق, جدا, او, ان, شي...
# 5   [restaurant, food, delicious, good, best, exce...
# 6   [mosque, god, الله, may, prayer, house, prophe...
# 7   [mall, سوق, market, shopping, one, الاسعار, اس...
# 8   [مغلق, سيء, جدا, سيئه, سيئ, سيئة, كورونا, bad,...
# 9   [place, هادئ, beautiful, peaceful, calm, quiet...
# 10  [family, place, good, للعائلات, nice, عائلي, t...
# 11  [يحتاج, تحتاج, الى, اهتمام, اكثر, تطوير, الاهت...
# 12  [fish, price, السمك, market, fresh, cheap, الأ...
# 13  [المياه, دورات, مياه, الحمامات, دوراة, toilet,...
# 14  [car, parking, get, drive, need, place, rememb...
# 15  [cinema, movie, hall, غني, التعريف, riyadh, ex...
# 16  [love, loved, falsefalse, place, tried, العشق,...
# 17  [الليل, view, time, evening, الاضاءة, night, ا...
# 18  [روعة, أجواء, خلابه, الطائرة, حطام, طائرة, pla...
# 19  [معلم, بأس, سياحي, احب, تاريخي, معالم, الاحساء...

# %%
#Checking TF-IDF scores for topic 0 (top 10 words are chosen by default based on TF-IDF scores)
topic_model.get_topic(0)
# Out:
# [('جدا', 0.08789999829008117),
#  ('ممتاز', 0.07766025722159918),
#  ('جميل', 0.06849276696433843),
#  ('رائع', 0.05866849517695567),
#  ('جيد', 0.04441122430908743),
#  ('جميله', 0.029987999982842586),
#  ('good', 0.02373100546387962),
#  ('جميلة', 0.020998406661044217),
#  ('ممتازة', 0.018104833966980247),
#  ('حلو', 0.017906077229401896)]

# %%
topic_model.visualize_topics()

# %%
#ADDING TOPIC REPRESENTATIONS LAYER
#Use chat-gpt from open AI to fine tune topic representations instead of manually coming up with themes

import openai
from bertopic.representation import OpenAI
import os

openai_api_key = os.environ['OPENAI_API_KEY']
client = openai.OpenAI(api_key=openai_api_key)

# Update topic representations using OpenAI
system_prompt="'You are an assistant that extracts high-level topics in english from customer review texts.'"
representation_model = OpenAI(client=client, model="gpt-4.1", system_prompt=system_prompt)

texts = final_df['clean_content'].astype(str).tolist()

topic_model.update_topics(docs=texts, representation_model=representation_model)

topic_info = topic_model.get_topic_info()
topic_info[['Topic', 'Name', 'Count', 'Representation']]
# Out:
#     Topic                                 Name  Count  \
# 0      -1      -1_Positive experience feedback     30
# 1       0         0_Positive customer feedback   2341
# 2       1          1_Beautiful park experience   1678
# 3       2     2_Hotel cleanliness satisfaction   1262
# 4       3  3_Historical landmarks Saudi Arabia   1162
# 5       4            4_Restaurant food quality    902
# 6       5               5_Islamic Holy Mosques    473
# 7       6                6_Best shopping malls    460
# 8       7          7_Temporarily Closed Venues    368
# 9       8           8_Peaceful Beautiful Place    213
# 10      9        9_Family-friendly destination    201
# 11     10             10_Need more improvement    198
# 12     11                11_Fresh fish quality    102
# 13     12       12_Bathroom cleanliness issues    127
# 14     13         13_Mountain access logistics    101
# 15     14          14_Cinema experience Riyadh     98
# 16     15             15_Customer appreciation     60
# 17     16       16_Nighttime lighting concerns     54
# 18     17          17_Stunning natural scenery     68
# 19     18       18_Tourist attractions Al-Ahsa     53
#
#                          Representation
# 0        [Positive experience feedback]
# 1          [Positive customer feedback]
# 2           [Beautiful park experience]
# 3      [Hotel cleanliness satisfaction]
# 4   [Historical landmarks Saudi Arabia]
# 5             [Restaurant food quality]
# 6                [Islamic Holy Mosques]
# 7                 [Best shopping malls]
# 8           [Temporarily Closed Venues]
# 9            [Peaceful Beautiful Place]
# 10        [Family-friendly destination]
# 11              [Need more improvement]
# 12                 [Fresh fish quality]
# 13        [Bathroom cleanliness issues]
# 14          [Mountain access logistics]
# 15           [Cinema experience Riyadh]
# 16              [Customer appreciation]
# 17        [Nighttime lighting concerns]
# 18           [Stunning natural scenery]
# 19        [Tourist attractions Al-Ahsa]

# %%
# Create a mapping from topic number to theme name
topic_to_theme = dict(zip(topic_info['Topic'],topic_info['Representation'].apply(lambda v: v[0] if isinstance(v, (list,tuple)) and len(v)==1 else v)))

# Assign theme to each review
final_df['theme_BERT'] = final_df['topic_BERT'].map(topic_to_theme)
final_df.drop('topic_BERT', axis=1, inplace=True)

# %%
final_df
# Out:
#                        id                      date language  \
# 0     377380-167052110186 2021-02-07 00:14:00+00:00      ara
# 1     377380-167053227344 2021-02-07 00:01:00+00:00      ara
# 2     377380-167056314181 2021-02-07 01:51:00+00:00      eng
# 3     377380-167057432860 2021-02-07 00:45:00+00:00      ara
# 4     377380-167058489640 2021-02-07 02:28:00+00:00      ara
# ...                   ...                       ...      ...
# 9946  377380-208857650522 2021-06-01 12:07:00+00:00      eng
# 9947  377380-225738358384 2022-10-17 11:16:00+00:00      ara
# 9948  377380-259913223515 2023-10-03 06:31:00+00:00      ara
# 9949  377380-259913232905 2023-10-03 02:30:00+00:00      ara
# 9950  377380-259913238900 2023-10-01 11:28:00+00:00      ara
#
#                                                   title  normalized_rating  \
# 0                           Hotel Raffles Makkah Palace              100.0
# 1                                    HYAT SHARMA RESORT               60.0
# 2                                         Novotel Yanbu               80.0
# 3     منتجع و سبا درة الرياض / Durrat Al Riyadh Reso...               80.0
# 4                                    ديم للغرف الفندقية               60.0
# ...                                                 ...                ...
# 9946                     Burger King - Riyadh Gallery 2              100.0
# 9947                                 Prince Hussam Park              100.0
# 9948                                      Arruddaf Park              100.0
# 9949                                      Arruddaf Park              100.0
# 9950                                      Arruddaf Park              100.0
#
#       actual_rating  offering_Accommodation  offering_Food & Beverage  \
# 0               5.0                       1                         0
# 1               3.0                       1                         0
# 2               4.0                       1                         0
# 3               4.0                       1                         1
# 4               3.0                       1                         0
# ...             ...                     ...                       ...
# 9946            5.0                       1                         1
# 9947            5.0                       0                         0
# 9948            5.0                       0                         0
# 9949            5.0                       0                         0
# 9950            5.0                       0                         0
#
#       offering_Retail  offering_Tourism Attractions/ Sites destination  \
# 0                   0                                    1      Makkah
# 1                   0                                    0       Tabuk
# 2                   0                                    0       Yanbu
# 3                   0                                    0      Riyadh
# 4                   0                                    0      Dammam
# ...               ...                                  ...         ...
# 9946                0                                    0      Riyadh
# 9947                0                                    1     Al Baha
# 9948                0                                    1        Taif
# 9949                0                                    1        Taif
# 9950                0                                    1        Taif
#
#      sentiment_lexicon sentiment_LLM  \
# 0              neutral      positive
# 1              neutral      positive
# 2             positive      positive
# 3              neutral      positive
# 4              neutral      positive
# ...                ...           ...
# 9946          positive      positive
# 9947           neutral      positive
# 9948           neutral      positive
# 9949           neutral      positive
# 9950           neutral       neutral
#
#                                           clean_content  \
# 0                             جميل جدن خدمه فاخره مميزه
# 1                                  مكان جميل شرما البحر
# 2                                            good hotel
# 3                        منتجع جميل يحتاج ترتيب وأهتمام
# 4                                جيده الاستقبال محترمين
# ...                                                 ...
# 9946                                          nice good
# 9947                                   رائعه وجميله جدا
# 9948                   أجمل متنزهات السعودية فعلآ رائعة
# 9949                                جمييييله جدا ورائعه
# 9950  المنتزه الرئيسي بمدينة الطائف يقصده السكان وال...
#
#                                       theme_LDA  \
# 0     Accommodation & Positive Venue Experience
# 1     Accommodation & Positive Venue Experience
# 2                   Food & Dining / Restaurants
# 3     Accommodation & Positive Venue Experience
# 4     Accommodation & Positive Venue Experience
# ...                                         ...
# 9946                Food & Dining / Restaurants
# 9947  Accommodation & Positive Venue Experience
# 9948      Attractions & Scenic / Heritage Sites
# 9949  Accommodation & Positive Venue Experience
# 9950     Religious / Spiritual & Tranquil Sites
#
#                              theme_BERT
# 0            Positive customer feedback
# 1             Beautiful park experience
# 2        Hotel cleanliness satisfaction
# 3                 Need more improvement
# 4            Positive customer feedback
# ...                                 ...
# 9946         Positive customer feedback
# 9947         Positive customer feedback
# 9948  Historical landmarks Saudi Arabia
# 9949         Positive customer feedback
# 9950  Historical landmarks Saudi Arabia
#
# [9951 rows x 16 columns]

# %% [markdown]
# #### Part 3: EDA

# %%
#Distribution of sentiments (LLM Based), offerings, destinations, ratings, and themes (BERTopic)
# Pie chart of sentiment counts (LLM-based)
sentiment_counts = final_df['sentiment_LLM'].value_counts()
labels = [f"{label} ({count})" for label, count in sentiment_counts.items()]

plt.figure(figsize=(3, 3))
plt.pie(
    sentiment_counts,
    labels=labels,
    autopct='%1.1f%%',
    startangle=90,
    counterclock=False
)
plt.title('Sentiment Distribution (LLM-based)')
plt.axis('equal')
plt.show()

# %%
# Distribution of offerings VS Sentiment
sentiment_colors = {
    'negative': '#E45756',
    'neutral': '#F2CF5B',
    'positive': '#54A24B'
}

offering_cols = [c for c in final_df.columns if c.startswith('offering_')]
plot_data = (
    final_df.melt(id_vars='sentiment_LLM', value_vars=offering_cols, var_name='offering', value_name='flag')
    .query('flag == 1')
    .assign(offering=lambda d: d['offering'].str.replace('offering_', '', regex=False))
)

stack_df = pd.crosstab(plot_data['offering'], plot_data['sentiment_LLM'])
stack_df = stack_df[[c for c in ['negative', 'neutral', 'positive'] if c in stack_df.columns]]

ax = stack_df.plot(
    kind='bar', stacked=True, figsize=(8, 5),
    color=[sentiment_colors[c] for c in stack_df.columns]
)

# segment percentages inside each colored bar
totals = stack_df.sum(axis=1)
for container in ax.containers:
    labels = [
        f"{(v / totals.iloc[i]):.0%}" if v > 0 else ""
        for i, v in enumerate(container.datavalues)
    ]
    ax.bar_label(container, labels=labels, label_type='center', fontsize=8, color='black')

# total count on top
for i, total in enumerate(totals):
    ax.text(i, total, f"{int(total)}", ha='center', va='bottom', fontweight='bold')

plt.title('Offering Distribution by Sentiment (LLM)')
plt.xlabel('Offering')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=15)
plt.legend(title='Sentiment', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Distribution of destinations VS Sentiment

import geopandas as gpd
import numpy as np
from matplotlib.lines import Line2D

# Sentiment counts by destination (LLM-based)
dest_sent = pd.crosstab(final_df['destination'], final_df['sentiment_LLM'])
sentiment_order = [c for c in ['negative', 'neutral', 'positive'] if c in dest_sent.columns]
dest_sent = dest_sent[sentiment_order]
total_reviews = dest_sent.sum(axis=1)
negative_count = dest_sent['negative']
negative_pct = (negative_count / total_reviews * 100)

# Approx. lon/lat for Saudi destinations (lon, lat)
coords = {
    "Abha": (42.50, 18.23),
    "Al Ahsa": (49.59, 25.38),
    "Al Baha": (41.47, 20.01),
    "Al Diriyah": (46.57, 24.73),
    "Al Namas": (42.12, 19.13),
    "Al Ula": (37.92, 26.60),
    "Dammam": (50.10, 26.42),
    "Hail": (41.70, 27.52),
    "Jeddah": (39.17, 21.54),
    "Jizan": (42.55, 16.89),
    "KAEC": (39.10, 22.45),
    "Khobar": (50.20, 26.28),
    "Madinah": (39.61, 24.47),
    "Makkah": (39.86, 21.39),
    "Qassim": (43.98, 26.36),
    "Riyadh": (46.67, 24.71),
    "Sakaka / AlJouf": (40.21, 29.97),
    "Tabuk": (36.56, 28.38),
    "Taif": (40.41, 21.27),
    "Tanomah": (42.13, 18.98),
    "Umluj": (37.26, 25.05),
    "Yanbu": (38.06, 24.09),
}

# Only keep destinations that have coordinates
dest_list = [d for d in dest_sent.index if d in coords]
top5 = negative_pct.loc[dest_list].sort_values(ascending=False).head(5).index

# Top total review count destinations
top_total = total_reviews.loc[dest_list].sort_values(ascending=False).head(5).index

# Base map
world = gpd.read_file("https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip")
sa = world[world['NAME'] == 'Saudi Arabia']
ax = sa.plot(color='#F2F2F2', edgecolor='gray', figsize=(8, 10))

max_total = total_reviews.loc[dest_list].max()

# Numbered legend mapping
dest_num = {d: i + 1 for i, d in enumerate(dest_list)}

# Offsets (dx, dy) for crowded labels
offsets = {
    "Riyadh": (0.8, 0.4),
    "Makkah": (-0.8, -0.4),
    "Jeddah": (-0.6, 0.6),
    "Madinah": (0.6, 0.6),
    "Dammam": (0.8, -0.6),
    "Khobar": (1.0, -0.2),
    "KAEC": (-0.6, -0.3),
    "Taif": (-0.6, -0.5),
    "Al Diriyah": (0.6, 0.2),
}

label_fontsize = 10
used_label_positions = []

def _resolve_overlap(x, y, used, thresh=0.35):
    if not used:
        return x, y
    for k in range(1, 12):
        angle = k * (np.pi / 4)
        dx = 0.2 * k * np.cos(angle)
        dy = 0.2 * k * np.sin(angle)
        nx, ny = x + dx, y + dy
        if all((nx - ux) ** 2 + (ny - uy) ** 2 > thresh ** 2 for ux, uy in used):
            return nx, ny
    return x, y

for dest in dest_list:
    x, y = coords[dest]
    total = total_reviews.loc[dest]
    if total == 0:
        continue

    size = 30 + 220 * np.sqrt(total / max_total)
    is_top5 = dest in top5
    is_top_total = dest in top_total
    dot_zorder = 5 if is_top5 else 3

    ax.scatter(
        x, y,
        s=size,
        color='red' if is_top5 else '#4C78A8',
        edgecolor='white',
        linewidth=0.6,
        zorder=dot_zorder
    )

    if is_top_total:
        ax.scatter(
            x, y,
            s=size * 1.6,
            facecolors='none',
            edgecolors='green',
            linewidth=1.6,
            zorder=6
        )

    dx, dy = offsets.get(dest, (0.0, 0.0))
    label_text = str(dest_num[dest])
    label_color = 'black'

    if dx == 0.0 and dy == 0.0:
        lx, ly = _resolve_overlap(x, y, used_label_positions)
        used_label_positions.append((lx, ly))
        ax.text(
            lx, ly, label_text,
            fontsize=label_fontsize, ha='center', va='center',
            color=label_color, fontweight='bold', zorder=4
        )
    else:
        lx, ly = x + dx, y + dy
        lx, ly = _resolve_overlap(lx, ly, used_label_positions)
        used_label_positions.append((lx, ly))
        ax.annotate(
            label_text,
            xy=(x, y),
            xytext=(lx, ly),
            textcoords='data',
            fontsize=label_fontsize,
            ha='center', va='center',
            color=label_color, fontweight='bold',
            arrowprops=dict(arrowstyle='-', color='gray', lw=0.5),
            zorder=4
        )

ax.set_xlim(34, 56)
ax.set_ylim(16, 33)
ax.set_axis_off()

legend_handles = [
    Line2D([0], [0], marker='o', color='w', label='★ Top 5 Negative Review %',
           markerfacecolor='red', markeredgecolor='white', markersize=8),
    Line2D([0], [0], marker='o', color='w', label='Other destinations',
           markerfacecolor='#4C78A8', markeredgecolor='white', markersize=8),
    Line2D([0], [0], marker='o', color='green', label='▲ Top 5 Total Reviews',
           markerfacecolor='none', markeredgecolor='green', markersize=8),
]
ax.legend(handles=legend_handles, loc='lower left', title='Highlight')

# Number legend for destinations (top right) with totals and negative %
# Mark top negative review destinations with a red indicator
num_legend_text = "\n".join([
    f"{dest_num[d]}: {d} (n={int(total_reviews.loc[d])}, {negative_pct.loc[d]:.1f}%)"
    + ("  ★" if d in top5 else "")
    + ("  ▲" if d in top_total else "")
    for d in dest_list
])
ax.text(0.98, 0.98, num_legend_text, transform=ax.transAxes,
        fontsize=7, va='top', ha='right',
        bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.8))

plt.title('Total Reviews and Negative Review Count by Destination (Saudi Arabia)')
plt.tight_layout()
plt.show()

# %%
# distribution of normalized ratings
plt.figure(figsize=(8, 5))
sns.histplot(final_df['normalized_rating'], bins=20, kde=True, color='#4C78A8')
plt.title('Distribution of Normalized Ratings') 
plt.xlabel('Normalized Rating')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# distribution of normalized rating per offering
plt.figure(figsize=(9, 5))

plot_data = (
    final_df.melt(id_vars='normalized_rating', value_vars=offering_cols, var_name='offering', value_name='flag')
    .query('flag == 1')
    .assign(offering=lambda d: d['offering'].str.replace('offering_', '', regex=False))
)

sns.histplot(
    data=plot_data,
    x='normalized_rating',
    hue='offering',
    kde=True,
    element='step',
    stat='count',
    common_norm=False
)

plt.title('Normalized Rating Distribution by Offering')
plt.xlabel('Normalized Rating')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Sentiment vs Offering

# %%
# Sentiment vs Destination

# %%
# Sentiment vs Rating

# %% [markdown]
# #### Part4: Future Scope
#
# The data now is cleaned and labeled with themes --> ready to train an NLP model
